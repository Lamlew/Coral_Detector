# %% [markdown]
# <a href="https://colab.research.google.com/github/Lamlew/Coral_Detector/blob/main/limelight-detector-training-notebook-7712-Lewi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![TrainingNotebookLogo.png](https://downloads.limelightvision.io/content/TrainingNotebookLogo.png)

# %% [markdown]
# To train a neural object detector for Limelight, click the "play" button on each code block. Pay extra attention to any "❗" you see. By the end of this tutorial, you will have downloaded a .zip file containing your model and label files.
#
# See https://docs.limelightvision.io/docs/docs-limelight/pipeline-neural/training-your-own-detector for a more in-depth tutorial.

# %% [markdown]
# # 1. Install The Object Detection Package

# %%
import shutil
import os
tmpModelPath ='/content/models'
if os.path.exists(tmpModelPath) and os.path.isdir(tmpModelPath):
  shutil.rmtree(tmpModelPath)

MLENVIRONMENT="COLAB"
# !git clone --depth 1 https://github.com/tensorflow/models
# !cd models && git fetch --depth 1 origin ad1f7b56943998864db8f5db0706950e93bb7d81 && git checkout ad1f7b56943998864db8f5db0706950e93bb7d81
# !pip install protobuf==3.20.3
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 4395, done.
# remote: Counting objects: 100% (4395/4395), done.
# remote: Compressing objects: 100% (3207/3207), done.
# remote: Total 4395 (delta 1189), reused 3089 (delta 1114), pack-reused 0 (from 0)
# Receiving objects: 100% (4395/4395), 70.05 MiB | 15.69 MiB/s, done.
# Resolving deltas: 100% (1189/1189), done.
# Updating files: 100% (3960/3960), done.
# remote: Enumerating objects: 3099, done.
# remote: Counting objects: 100% (3099/3099), done.
# remote: Compressing objects: 100% (1386/1386), done.
# remote: Total 1851 (delta 1243), reused 705 (delta 446), pack-reused 0 (from 0)
# Receiving objects: 100% (1851/1851), 10.08 MiB | 10.89 MiB/s, done.
# Resolving deltas: 100% (1243/1243), completed with 758 local objects.
# From https://github.com/tensorflow/models
#  * branch            ad1f7b56943998864db8f5db0706950e93bb7d81 -> FETCH_HEAD
# Updating files: 100% (1983/1983), done.
# Note: switching to 'ad1f7b56943998864db8f5db0706950e93bb7d81'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at ad1f7b5 adjust folder path
# Collecting protobuf==3.20.3
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# tensorflow-metadata 1.17.2 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed protobuf-3.20.3

# %%
# Environment Setup
import os
import sys
import re

print(sys.version)
if(MLENVIRONMENT == "COLAB"):
    print("colab env setup")
    os.environ["HOMEFOLDER"] = "/content/"
    HOMEFOLDER = '{HOMEFOLDER}'.format(**os.environ)
    FINALOUTPUTFOLDER_DIRNAME = 'final_output'
    FINALOUTPUTFOLDER = HOMEFOLDER+FINALOUTPUTFOLDER_DIRNAME
    print(HOMEFOLDER)

# Copy setup files into models/research folder
# !cd {HOMEFOLDER}models/research && pwd && protoc object_detection/protos/*.proto --python_out=.

# Modify setup.py
with open(HOMEFOLDER+'models/research/object_detection/packages/tf2/setup.py') as f:
    s = f.read()

with open(HOMEFOLDER+'models/research/setup.py', 'w') as f:
    if(MLENVIRONMENT == "COLAB"):
        s = re.sub('tf-models-official>=2.5.1','tf-models-official==2.15.0', s)
        f.write(s)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# colab env setup
# /content/
# /content/models/research

# %%
# Install
# !pip install {HOMEFOLDER}models/research/
if(MLENVIRONMENT == "COLAB"):
    # !pip install tensorflow==2.15.0
    # !pip install protobuf==3.20.3
# Out:
# Processing ./models/research
#   Preparing metadata (setup.py) ... done
# Collecting avro-python3 (from object_detection==0.1)
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Collecting apache-beam (from object_detection==0.1)
#   Downloading apache_beam-2.70.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from object_detection==0.1) (11.3.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from object_detection==0.1) (6.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from object_detection==0.1) (3.10.0)
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from object_detection==0.1) (3.0.12)
# Collecting contextlib2 (from object_detection==0.1)
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tf-slim in /usr/local/lib/python3.12/dist-packages (from object_detection==0.1) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from object_detection==0.1) (1.17.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.12/dist-packages (from object_detection==0.1) (2.0.10)
# Collecting lvis (from object_detection==0.1)
#   Downloading lvis-0.5.3-py3-none-any.whl.metadata (856 bytes)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from object_detection==0.1) (1.16.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from object_detection==0.1) (2.2.2)
# Collecting tf-models-official==2.15.0 (from object_detection==0.1)
#   Downloading tf_models_official-2.15.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting tensorflow_io (from object_detection==0.1)
#   Downloading tensorflow_io-0.37.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (from object_detection==0.1) (3.10.0)
# Collecting pyparsing==2.4.7 (from object_detection==0.1)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting sacrebleu<=2.2.0 (from object_detection==0.1)
#   Downloading sacrebleu-2.2.0-py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: gin-config in /usr/local/lib/python3.12/dist-packages (from tf-models-official==2.15.0->object_detection==0.1) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.12/dist-packages (from tf-models-official==2.15.0->object_detection==0.1) (2.187.0)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.12/dist-packages (from tf-models-official==2.15.0->object_detection==0.1) (4.2.2)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.12/dist-packages (from tf-models-official==2.15.0->object_detection==0.1) (1.7.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.12/dist-packages (from tf-models-official==2.15.0->object_detection==0.1) (2.0.2)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.12/dist-packages (from tf-models-official==2.15.0->object_detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from tf-models-official==2.15.0->object_detection==0.1) (4.12.0.88)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.12/dist-packages (from tf-models-official==2.15.0->object_detection==0.1) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from tf-models-official==2.15.0->object_detection==0.1) (9.0.0)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from tf-models-official==2.15.0->object_detection==0.1) (6.0.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from tf-models-official==2.15.0->object_detection==0.1) (0.2.1)
# Collecting seqeval (from tf-models-official==2.15.0->object_detection==0.1)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.12/dist-packages (from tf-models-official==2.15.0->object_detection==0.1) (4.9.9)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from tf-models-official==2.15.0->object_detection==0.1) (0.16.1)
# Collecting tensorflow-model-optimization>=0.4.1 (from tf-models-official==2.15.0->object_detection==0.1)
#   Downloading tensorflow_model_optimization-0.8.0-py2.py3-none-any.whl.metadata (904 bytes)
# INFO: pip is looking at multiple versions of tf-models-official to determine which version is compatible with other requirements. This could take a while.
# ERROR: Ignored the following versions that require a different python version: 0.37.0 Requires-Python <3.12,>=3.7; 2.10.0 Requires-Python >=2.7,<3.0; 2.3.0 Requires-Python >=2.7,<3.0; 2.4.0 Requires-Python >=2.7,<3.0; 2.5.0 Requires-Python >=2.7,<3.0; 2.6.0 Requires-Python >=2.7,<3.0; 2.7.0 Requires-Python >=2.7,<3.0; 2.8.0 Requires-Python >=2.7,<3.0; 2.9.0 Requires-Python >=2.7,<3.0
# ERROR: Could not find a version that satisfies the requirement tensorflow-text~=2.15.0 (from tf-models-official) (from versions: 2.18.1, 2.19.0rc0, 2.19.0)
# ERROR: No matching distribution found for tensorflow-text~=2.15.0
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.15.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0)
# ERROR: No matching distribution found for tensorflow==2.15.0
# Requirement already satisfied: protobuf==3.20.3 in /usr/local/lib/python3.12/dist-packages (3.20.3)

# %% [markdown]
# Test the environment by running `model_builder_tf2_test.py` to make sure everything is working as expected.

# %%
# !python {HOMEFOLDER}models/research/object_detection/builders/model_builder_tf2_test.py
# Out:
# 2025-12-24 00:23:08.714594: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-24 00:23:08.727722: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-24 00:23:08.785877: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766535788.857205    1020 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766535788.873838    1020 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766535788.901825    1020 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766535788.901980    1020 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766535788.901993    1020 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766535788.902005    1020 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-24 00:23:08.917960: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/models/research/object_detection/builders/model_builder_tf2_test.py", line 24, in <module>
#     from object_detection.builders import model_builder
# ModuleNotFoundError: No module named 'object_detection'

# %% [markdown]
# # 1.1. Get Dataset From Google Drive
#
# 1. Expand this section
# 2. Upload your RoboFlow .tfrecord.zip to Google Drive
# 3. Share the uploaded .tfrecord.zip such that anyone with the link can access the file.
# 4. Run this block
# 5. Paste your Google Drive file share link into the text box that appears after running this block
# 6. Click the "Process Dataset" Buttton
# 7. Click the Refresh button in the "Files" pane to ensure dataset.zip exists

# %%
import gdown
import os
from IPython.display import display
from ipywidgets import Text, Button, VBox

def process_dataset():
    link_input = Text(
        value='',
        placeholder='https://drive.google.com/file/d/1FlqvG4eFrQbOTcYFNqBFoVnALkICRPOi/view?usp=sharing',
        description='Drive Link: ',
        style={'description_width': 'initial'},
        layout={'width': '50%'}
    )

    def on_click(b):
        try:
            print("Downloading dataset...")
            url = link_input.value

            # Convert share URL to direct download URL if needed
            if 'drive.google.com/file/d/' in url:
                file_id = url.split('/file/d/')[1].split('/')[0]
                url = f'https://drive.google.com/uc?id={file_id}'

            output = '/content/dataset.zip'
            gdown.download(url, output, fuzzy=True)
            print("Download complete!")

        except Exception as e:
            print(f"Error: {str(e)}")

    process_button = Button(description='Process Dataset', button_style='primary')
    process_button.on_click(on_click)
    display(VBox([link_input, process_button]))

# Install gdown if not already installed
# !pip install -q gdown --upgrade

# Execute
process_dataset()
# Out:
# VBox(children=(Text(value='', description='Drive Link: ', layout=Layout(width='50%'), placeholder='https://dri…
# Downloading dataset...
# Downloading...
# From (original): https://drive.google.com/uc?id=1FlqvG4eFrQbOTcYFNqBFoVnALkICRPOi
# From (redirected): https://drive.google.com/uc?id=1FlqvG4eFrQbOTcYFNqBFoVnALkICRPOi&confirm=t&uuid=e1d795d4-adc4-4765-95de-6c836b3ac24c
# To: /content/dataset.zip
# 100%|██████████| 68.6M/68.6M [00:00<00:00, 123MB/s]
# Download complete!

# %% [markdown]
# # 2. Auto-detect relevant tfrecord components

# %%
datasetPath = '/content/dataset.zip'
print(datasetPath)
# !unzip $datasetPath
# Out:
# /content/dataset.zip
# Archive:  /content/dataset.zip
#   inflating: README.roboflow.txt
#    creating: test/
#  extracting: test/IMG_4906_JPG.rf.4997ea62ea5f767f8f8cdba27b464520.jpg
#   inflating: test/IMG_4906_JPG.rf.4997ea62ea5f767f8f8cdba27b464520.xml
#  extracting: test/IMG_4906_JPG.rf.7656dad4d02d87b2f8226da65657e8db.jpg
#   inflating: test/IMG_4906_JPG.rf.7656dad4d02d87b2f8226da65657e8db.xml
#  extracting: test/IMG_4906_JPG.rf.849aeebf44d1514517b73e3331948bb0.jpg
#   inflating: test/IMG_4906_JPG.rf.849aeebf44d1514517b73e3331948bb0.xml
#  extracting: test/IMG_4906_JPG.rf.d8b2bd52481d0ec1028b8ae6c7db9bda.jpg
#   inflating: test/IMG_4906_JPG.rf.d8b2bd52481d0ec1028b8ae6c7db9bda.xml
#  extracting: test/IMG_4917_JPG.rf.5b15b0a8ad1dec179f7799f6fdb133fe.jpg
#   inflating: test/IMG_4917_JPG.rf.5b15b0a8ad1dec179f7799f6fdb133fe.xml
#  extracting: test/IMG_4917_JPG.rf.90aa011ce007a3d188f562351ecf0e9b.jpg
#   inflating: test/IMG_4917_JPG.rf.90aa011ce007a3d188f562351ecf0e9b.xml
#  extracting: test/IMG_4917_JPG.rf.cf65209d7bb653ecb608a65351da3d92.jpg
#   inflating: test/IMG_4917_JPG.rf.cf65209d7bb653ecb608a65351da3d92.xml
#  extracting: test/IMG_4917_JPG.rf.e8681314e4b70d4a9263a3aef149661d.jpg
#   inflating: test/IMG_4917_JPG.rf.e8681314e4b70d4a9263a3aef149661d.xml
#  extracting: test/IMG_4925_JPG.rf.aa9c2374b7cadb78200d08a2175427e6.jpg
#   inflating: test/IMG_4925_JPG.rf.aa9c2374b7cadb78200d08a2175427e6.xml
#  extracting: test/IMG_4925_JPG.rf.c4aa822f69730362d193f3a53a2d4072.jpg
#   inflating: test/IMG_4925_JPG.rf.c4aa822f69730362d193f3a53a2d4072.xml
#  extracting: test/IMG_4925_JPG.rf.c897e7359c241deca71d3cc60340330b.jpg
#   inflating: test/IMG_4925_JPG.rf.c897e7359c241deca71d3cc60340330b.xml
#  extracting: test/IMG_4925_JPG.rf.c8d24dcc646e10ac24c3bfa0d580db2a.jpg
#   inflating: test/IMG_4925_JPG.rf.c8d24dcc646e10ac24c3bfa0d580db2a.xml
#  extracting: test/IMG_4932_JPG.rf.5068d7c6c022d85c3bbb03ebc0f5461b.jpg
#   inflating: test/IMG_4932_JPG.rf.5068d7c6c022d85c3bbb03ebc0f5461b.xml
#  extracting: test/IMG_4932_JPG.rf.7d88ae635ae58c34df99d29e277aafe2.jpg
#   inflating: test/IMG_4932_JPG.rf.7d88ae635ae58c34df99d29e277aafe2.xml
#  extracting: test/IMG_4932_JPG.rf.b3be06fd5e36f4fa3f385626a1c043b6.jpg
#   inflating: test/IMG_4932_JPG.rf.b3be06fd5e36f4fa3f385626a1c043b6.xml
#  extracting: test/IMG_4932_JPG.rf.f6f96c0f3dd8b43b05059142533f60d6.jpg
#   inflating: test/IMG_4932_JPG.rf.f6f96c0f3dd8b43b05059142533f60d6.xml
#  extracting: test/IMG_4937_JPG.rf.0762b454f882dc01124fb0331c6d7361.jpg
#   inflating: test/IMG_4937_JPG.rf.0762b454f882dc01124fb0331c6d7361.xml
#  extracting: test/IMG_4937_JPG.rf.4086bb061c4a712bfae5a6e57f41e449.jpg
#   inflating: test/IMG_4937_JPG.rf.4086bb061c4a712bfae5a6e57f41e449.xml
#  extracting: test/IMG_4937_JPG.rf.eb1b471caf3927552fbcbc44bc058517.jpg
#   inflating: test/IMG_4937_JPG.rf.eb1b471caf3927552fbcbc44bc058517.xml
#  extracting: test/IMG_4937_JPG.rf.fc9c61d1c525ca1152c9d5494c823fe8.jpg
#   inflating: test/IMG_4937_JPG.rf.fc9c61d1c525ca1152c9d5494c823fe8.xml
#  extracting: test/IMG_4947_JPG.rf.38c8a4a4aebfc4da6df74040269461d8.jpg
#   inflating: test/IMG_4947_JPG.rf.38c8a4a4aebfc4da6df74040269461d8.xml
#  extracting: test/IMG_4947_JPG.rf.660e7ecee2809537bf5cc2228d5b268c.jpg
#   inflating: test/IMG_4947_JPG.rf.660e7ecee2809537bf5cc2228d5b268c.xml
#  extracting: test/IMG_4947_JPG.rf.a1e347a46bca7f5c814bbc1bf5389461.jpg
#   inflating: test/IMG_4947_JPG.rf.a1e347a46bca7f5c814bbc1bf5389461.xml
#  extracting: test/IMG_4947_JPG.rf.e029e6c0e6ead74e03d43a44e56384ec.jpg
#   inflating: test/IMG_4947_JPG.rf.e029e6c0e6ead74e03d43a44e56384ec.xml
#  extracting: test/IMG_4954_JPG.rf.5fac8a977c3a07b49c6e7367bc598974.jpg
#   inflating: test/IMG_4954_JPG.rf.5fac8a977c3a07b49c6e7367bc598974.xml
#  extracting: test/IMG_4954_JPG.rf.b4de4ad7e620213f86ce59f71c96a205.jpg
#   inflating: test/IMG_4954_JPG.rf.b4de4ad7e620213f86ce59f71c96a205.xml
#  extracting: test/IMG_4954_JPG.rf.d1b856a4fc73ec6693f86b57a3d733f4.jpg
#   inflating: test/IMG_4954_JPG.rf.d1b856a4fc73ec6693f86b57a3d733f4.xml
#  extracting: test/IMG_4954_JPG.rf.dd9f7afc48ad01fb55a2ab4bc3578af3.jpg
#   inflating: test/IMG_4954_JPG.rf.dd9f7afc48ad01fb55a2ab4bc3578af3.xml
#  extracting: test/IMG_4961_JPG.rf.a5e8b87c2869b9d0bf367b44c61ba8b1.jpg
#   inflating: test/IMG_4961_JPG.rf.a5e8b87c2869b9d0bf367b44c61ba8b1.xml
#  extracting: test/IMG_4961_JPG.rf.ae8818d77dc784d00c53dac5e1e987b2.jpg
#   inflating: test/IMG_4961_JPG.rf.ae8818d77dc784d00c53dac5e1e987b2.xml
#  extracting: test/IMG_4961_JPG.rf.e7797193467d382810c4c1bea920c254.jpg
#   inflating: test/IMG_4961_JPG.rf.e7797193467d382810c4c1bea920c254.xml
#  extracting: test/IMG_4961_JPG.rf.efeb9fd9c122b713ea651a1c3168b237.jpg
#   inflating: test/IMG_4961_JPG.rf.efeb9fd9c122b713ea651a1c3168b237.xml
#  extracting: test/IMG_4963_JPG.rf.2179a063abc435b698ae3350c9a187d5.jpg
#   inflating: test/IMG_4963_JPG.rf.2179a063abc435b698ae3350c9a187d5.xml
#  extracting: test/IMG_4963_JPG.rf.47f2260de1199b3d3f3935ca90ebddf0.jpg
#   inflating: test/IMG_4963_JPG.rf.47f2260de1199b3d3f3935ca90ebddf0.xml
#  extracting: test/IMG_4963_JPG.rf.778ea8370bab700e275671743d91af86.jpg
#   inflating: test/IMG_4963_JPG.rf.778ea8370bab700e275671743d91af86.xml
#  extracting: test/IMG_4963_JPG.rf.894f26cc999b0148ea516410f1d04dc1.jpg
#   inflating: test/IMG_4963_JPG.rf.894f26cc999b0148ea516410f1d04dc1.xml
#    creating: train/
#  extracting: train/IMG_4905_JPG.rf.01f83d03dd9f2381e9e1b155a8c2db58.jpg
#   inflating: train/IMG_4905_JPG.rf.01f83d03dd9f2381e9e1b155a8c2db58.xml
#  extracting: train/IMG_4905_JPG.rf.020836ac6e1990bedbf6f2e8967531db.jpg
#   inflating: train/IMG_4905_JPG.rf.020836ac6e1990bedbf6f2e8967531db.xml
#  extracting: train/IMG_4905_JPG.rf.07505b2350de038d6a8b9876b7996683.jpg
#   inflating: train/IMG_4905_JPG.rf.07505b2350de038d6a8b9876b7996683.xml
#  extracting: train/IMG_4905_JPG.rf.07d270e48ca6c5ea9ada0dad5f496145.jpg
#   inflating: train/IMG_4905_JPG.rf.07d270e48ca6c5ea9ada0dad5f496145.xml
#  extracting: train/IMG_4905_JPG.rf.08c7bd8ce6de01e84cb4fd3c1d338630.jpg
#   inflating: train/IMG_4905_JPG.rf.08c7bd8ce6de01e84cb4fd3c1d338630.xml
#  extracting: train/IMG_4905_JPG.rf.0c577c67b3613e8c6d1649d220956643.jpg
#   inflating: train/IMG_4905_JPG.rf.0c577c67b3613e8c6d1649d220956643.xml
#  extracting: train/IMG_4905_JPG.rf.185622a71a5d14d337987b21aee8dd99.jpg
#   inflating: train/IMG_4905_JPG.rf.185622a71a5d14d337987b21aee8dd99.xml
#  extracting: train/IMG_4905_JPG.rf.227c25a6e86954bc9c9dc906a02e9ef4.jpg
#   inflating: train/IMG_4905_JPG.rf.227c25a6e86954bc9c9dc906a02e9ef4.xml
#  extracting: train/IMG_4905_JPG.rf.229b1b56d4ee2c03616e3a8b9c7a2149.jpg
#   inflating: train/IMG_4905_JPG.rf.229b1b56d4ee2c03616e3a8b9c7a2149.xml
#  extracting: train/IMG_4905_JPG.rf.237fbfd62e22c52e4c9e8d2009da1e75.jpg
#   inflating: train/IMG_4905_JPG.rf.237fbfd62e22c52e4c9e8d2009da1e75.xml
#  extracting: train/IMG_4905_JPG.rf.27d4c90581468b37badab033b70f0735.jpg
#   inflating: train/IMG_4905_JPG.rf.27d4c90581468b37badab033b70f0735.xml
#  extracting: train/IMG_4905_JPG.rf.31c7093dcdf6b1aa1cc792e003ac393e.jpg
#   inflating: train/IMG_4905_JPG.rf.31c7093dcdf6b1aa1cc792e003ac393e.xml
#  extracting: train/IMG_4905_JPG.rf.3bec07d7b15894706fe305e5f537b315.jpg
#   inflating: train/IMG_4905_JPG.rf.3bec07d7b15894706fe305e5f537b315.xml
#  extracting: train/IMG_4905_JPG.rf.437b1dd298c0e2ef13da4b4277258827.jpg
#   inflating: train/IMG_4905_JPG.rf.437b1dd298c0e2ef13da4b4277258827.xml
#  extracting: train/IMG_4905_JPG.rf.4472cf8b6574497743cac1ff5f487643.jpg
#   inflating: train/IMG_4905_JPG.rf.4472cf8b6574497743cac1ff5f487643.xml
#  extracting: train/IMG_4905_JPG.rf.458ebfb60ffecf0cc6609ead728016dd.jpg
#   inflating: train/IMG_4905_JPG.rf.458ebfb60ffecf0cc6609ead728016dd.xml
#  extracting: train/IMG_4905_JPG.rf.48217053e1b1eec73f320d8be281db47.jpg
#   inflating: train/IMG_4905_JPG.rf.48217053e1b1eec73f320d8be281db47.xml
#  extracting: train/IMG_4905_JPG.rf.583bd0f75ed9e0e7de2d955f1d73ea62.jpg
#   inflating: train/IMG_4905_JPG.rf.583bd0f75ed9e0e7de2d955f1d73ea62.xml
#  extracting: train/IMG_4905_JPG.rf.6b213b0b4a8565fde718967d1233da12.jpg
#   inflating: train/IMG_4905_JPG.rf.6b213b0b4a8565fde718967d1233da12.xml
#  extracting: train/IMG_4905_JPG.rf.6b6c66bbfc5fe3d4aa01bfb725d4bb58.jpg
#   inflating: train/IMG_4905_JPG.rf.6b6c66bbfc5fe3d4aa01bfb725d4bb58.xml
#  extracting: train/IMG_4905_JPG.rf.6d26bb7075e15793eb5961e8b5df8ebf.jpg
#   inflating: train/IMG_4905_JPG.rf.6d26bb7075e15793eb5961e8b5df8ebf.xml
#  extracting: train/IMG_4905_JPG.rf.73797b69a23a5c6b69503428992584ec.jpg
#   inflating: train/IMG_4905_JPG.rf.73797b69a23a5c6b69503428992584ec.xml
#  extracting: train/IMG_4905_JPG.rf.792b0973600493c837b3cc320ed09b41.jpg
#   inflating: train/IMG_4905_JPG.rf.792b0973600493c837b3cc320ed09b41.xml
#  extracting: train/IMG_4905_JPG.rf.7b502cf6c7fb2631271dc45eddbe29d7.jpg
#   inflating: train/IMG_4905_JPG.rf.7b502cf6c7fb2631271dc45eddbe29d7.xml
#  extracting: train/IMG_4905_JPG.rf.7d2952efdd93be86b04181114a425e40.jpg
#   inflating: train/IMG_4905_JPG.rf.7d2952efdd93be86b04181114a425e40.xml
#  extracting: train/IMG_4905_JPG.rf.7ec393123a46e878367d87607fa9ad00.jpg
#   inflating: train/IMG_4905_JPG.rf.7ec393123a46e878367d87607fa9ad00.xml
#  extracting: train/IMG_4905_JPG.rf.908349e20c586b7a3a7c020475b4da89.jpg
#   inflating: train/IMG_4905_JPG.rf.908349e20c586b7a3a7c020475b4da89.xml
#  extracting: train/IMG_4905_JPG.rf.994b3a46ae09596d2af5f94ab9de8c51.jpg
#   inflating: train/IMG_4905_JPG.rf.994b3a46ae09596d2af5f94ab9de8c51.xml
#  extracting: train/IMG_4905_JPG.rf.9b4b8556b7e7a9f0790631781d761aec.jpg
#   inflating: train/IMG_4905_JPG.rf.9b4b8556b7e7a9f0790631781d761aec.xml
#  extracting: train/IMG_4905_JPG.rf.9bd52ce8904e71344d0b1e36ce172994.jpg
#   inflating: train/IMG_4905_JPG.rf.9bd52ce8904e71344d0b1e36ce172994.xml
#  extracting: train/IMG_4905_JPG.rf.a1b8184b9b33cb5d9ef6e5518be39731.jpg
#   inflating: train/IMG_4905_JPG.rf.a1b8184b9b33cb5d9ef6e5518be39731.xml
#  extracting: train/IMG_4905_JPG.rf.b8655224e3b35a420a1253eecdfbb578.jpg
#   inflating: train/IMG_4905_JPG.rf.b8655224e3b35a420a1253eecdfbb578.xml
#  extracting: train/IMG_4905_JPG.rf.ba5361eb6ebe7f2b0ebb5dd0812597fe.jpg
#   inflating: train/IMG_4905_JPG.rf.ba5361eb6ebe7f2b0ebb5dd0812597fe.xml
#  extracting: train/IMG_4905_JPG.rf.c67442f21f471e81b90731e6bd9a64e1.jpg
#   inflating: train/IMG_4905_JPG.rf.c67442f21f471e81b90731e6bd9a64e1.xml
#  extracting: train/IMG_4905_JPG.rf.d2650273e2ecfd6075286e886a9aa946.jpg
#   inflating: train/IMG_4905_JPG.rf.d2650273e2ecfd6075286e886a9aa946.xml
#  extracting: train/IMG_4905_JPG.rf.f28623657d30a11072ef5deeb4511e19.jpg
#   inflating: train/IMG_4905_JPG.rf.f28623657d30a11072ef5deeb4511e19.xml
#  extracting: train/IMG_4905_JPG.rf.f36c040f189d36b13f9c3c7f5e8869df.jpg
#   inflating: train/IMG_4905_JPG.rf.f36c040f189d36b13f9c3c7f5e8869df.xml
#  extracting: train/IMG_4905_JPG.rf.fc3ac5005e9943b36688eb1451b56899.jpg
#   inflating: train/IMG_4905_JPG.rf.fc3ac5005e9943b36688eb1451b56899.xml
#  extracting: train/IMG_4905_JPG.rf.fd6300e50758753942b05ab2d9fb9c3b.jpg
#   inflating: train/IMG_4905_JPG.rf.fd6300e50758753942b05ab2d9fb9c3b.xml
#  extracting: train/IMG_4905_JPG.rf.fdda6411ac864582980d87b15340c37d.jpg
#   inflating: train/IMG_4905_JPG.rf.fdda6411ac864582980d87b15340c37d.xml
#  extracting: train/IMG_4907_JPG.rf.03c07aee83eb0f0de44e4e9612324d5f.jpg
#   inflating: train/IMG_4907_JPG.rf.03c07aee83eb0f0de44e4e9612324d5f.xml
#  extracting: train/IMG_4907_JPG.rf.0d8e0fe4c6b1953f10723d1ce8d07670.jpg
#   inflating: train/IMG_4907_JPG.rf.0d8e0fe4c6b1953f10723d1ce8d07670.xml
#  extracting: train/IMG_4907_JPG.rf.11318079d0c3c8e9bd706a60f0713a34.jpg
#   inflating: train/IMG_4907_JPG.rf.11318079d0c3c8e9bd706a60f0713a34.xml
#  extracting: train/IMG_4907_JPG.rf.191850a17d90318414ec8daf3c48a589.jpg
#   inflating: train/IMG_4907_JPG.rf.191850a17d90318414ec8daf3c48a589.xml
#  extracting: train/IMG_4907_JPG.rf.1d6ec54d91fd6acd3f18fff587df31e9.jpg
#   inflating: train/IMG_4907_JPG.rf.1d6ec54d91fd6acd3f18fff587df31e9.xml
#  extracting: train/IMG_4907_JPG.rf.3d3477be677f3d2b9d308a140226c758.jpg
#   inflating: train/IMG_4907_JPG.rf.3d3477be677f3d2b9d308a140226c758.xml
#  extracting: train/IMG_4907_JPG.rf.3d688f9c30c1b7b76f24b5dc81e820e6.jpg
#   inflating: train/IMG_4907_JPG.rf.3d688f9c30c1b7b76f24b5dc81e820e6.xml
#  extracting: train/IMG_4907_JPG.rf.4b1819f5cd883c86b12da3888e690ae0.jpg
#   inflating: train/IMG_4907_JPG.rf.4b1819f5cd883c86b12da3888e690ae0.xml
#  extracting: train/IMG_4907_JPG.rf.54f854024386464285cdfa21d3d4650e.jpg
#   inflating: train/IMG_4907_JPG.rf.54f854024386464285cdfa21d3d4650e.xml
#  extracting: train/IMG_4907_JPG.rf.59fab6220fb6e62d6fd7cfc23ca69c90.jpg
#   inflating: train/IMG_4907_JPG.rf.59fab6220fb6e62d6fd7cfc23ca69c90.xml
#  extracting: train/IMG_4907_JPG.rf.5c55083254f86ab355b8a3d7fe6feeb7.jpg
#   inflating: train/IMG_4907_JPG.rf.5c55083254f86ab355b8a3d7fe6feeb7.xml
#  extracting: train/IMG_4907_JPG.rf.60c2c303532d2fe0d129f629e77896fe.jpg
#   inflating: train/IMG_4907_JPG.rf.60c2c303532d2fe0d129f629e77896fe.xml
#  extracting: train/IMG_4907_JPG.rf.6ecac7c3f129ebb8cb5dff2220001d3f.jpg
#   inflating: train/IMG_4907_JPG.rf.6ecac7c3f129ebb8cb5dff2220001d3f.xml
#  extracting: train/IMG_4907_JPG.rf.7563f354848582146b9620c8e100e263.jpg
#   inflating: train/IMG_4907_JPG.rf.7563f354848582146b9620c8e100e263.xml
#  extracting: train/IMG_4907_JPG.rf.756a70428bcc927d62235ba7ba8c0fb7.jpg
#   inflating: train/IMG_4907_JPG.rf.756a70428bcc927d62235ba7ba8c0fb7.xml
#  extracting: train/IMG_4907_JPG.rf.80b83391d7e9740b40853fd639bc3b40.jpg
#   inflating: train/IMG_4907_JPG.rf.80b83391d7e9740b40853fd639bc3b40.xml
#  extracting: train/IMG_4907_JPG.rf.8c302efd4f8bd8cd691354a8c1ead9c7.jpg
#   inflating: train/IMG_4907_JPG.rf.8c302efd4f8bd8cd691354a8c1ead9c7.xml
#  extracting: train/IMG_4907_JPG.rf.9023b06c1af0dd9a47d22b78991fb43d.jpg
#   inflating: train/IMG_4907_JPG.rf.9023b06c1af0dd9a47d22b78991fb43d.xml
#  extracting: train/IMG_4907_JPG.rf.9383cf70e39142187ab4c24622e64e11.jpg
#   inflating: train/IMG_4907_JPG.rf.9383cf70e39142187ab4c24622e64e11.xml
#  extracting: train/IMG_4907_JPG.rf.9902c4dde395dae26c8a6cd851580f8e.jpg
#   inflating: train/IMG_4907_JPG.rf.9902c4dde395dae26c8a6cd851580f8e.xml
#  extracting: train/IMG_4907_JPG.rf.a1b94cb2dfa4ccfdcc8708d89e61c842.jpg
#   inflating: train/IMG_4907_JPG.rf.a1b94cb2dfa4ccfdcc8708d89e61c842.xml
#  extracting: train/IMG_4907_JPG.rf.aace65c5c3f66e06c8e55a8e37f1c568.jpg
#   inflating: train/IMG_4907_JPG.rf.aace65c5c3f66e06c8e55a8e37f1c568.xml
#  extracting: train/IMG_4907_JPG.rf.afcd606e21d5c56a06cdcf2bbd489c90.jpg
#   inflating: train/IMG_4907_JPG.rf.afcd606e21d5c56a06cdcf2bbd489c90.xml
#  extracting: train/IMG_4907_JPG.rf.b15db9ec21c057dccaa931343be6f6e6.jpg
#   inflating: train/IMG_4907_JPG.rf.b15db9ec21c057dccaa931343be6f6e6.xml
#  extracting: train/IMG_4907_JPG.rf.b3ac6eb239b73ec4f01017b3d7a7f8fd.jpg
#   inflating: train/IMG_4907_JPG.rf.b3ac6eb239b73ec4f01017b3d7a7f8fd.xml
#  extracting: train/IMG_4907_JPG.rf.be6498397c2d318fa73c537d2e333b5a.jpg
#   inflating: train/IMG_4907_JPG.rf.be6498397c2d318fa73c537d2e333b5a.xml
#  extracting: train/IMG_4907_JPG.rf.c03f223991adf88963c25e988b8788c0.jpg
#   inflating: train/IMG_4907_JPG.rf.c03f223991adf88963c25e988b8788c0.xml
#  extracting: train/IMG_4907_JPG.rf.c0b33ce5fa3b3303e1f626a22a30efe1.jpg
#   inflating: train/IMG_4907_JPG.rf.c0b33ce5fa3b3303e1f626a22a30efe1.xml
#  extracting: train/IMG_4907_JPG.rf.c135d6d169e492ac080134077628eb7e.jpg
#   inflating: train/IMG_4907_JPG.rf.c135d6d169e492ac080134077628eb7e.xml
#  extracting: train/IMG_4907_JPG.rf.cd02eeb5638a12eb36df53232a0c375a.jpg
#   inflating: train/IMG_4907_JPG.rf.cd02eeb5638a12eb36df53232a0c375a.xml
#  extracting: train/IMG_4907_JPG.rf.cdaef16830d80cd7e4ce35a75081c130.jpg
#   inflating: train/IMG_4907_JPG.rf.cdaef16830d80cd7e4ce35a75081c130.xml
#  extracting: train/IMG_4907_JPG.rf.d9301d6d8d787d9cbb6f62b8fbcd2ec4.jpg
#   inflating: train/IMG_4907_JPG.rf.d9301d6d8d787d9cbb6f62b8fbcd2ec4.xml
#  extracting: train/IMG_4907_JPG.rf.dc78435643d2d951eab693ccadcb68f6.jpg
#   inflating: train/IMG_4907_JPG.rf.dc78435643d2d951eab693ccadcb68f6.xml
#  extracting: train/IMG_4907_JPG.rf.e016f21a18163d58c14a12bb78f0a311.jpg
#   inflating: train/IMG_4907_JPG.rf.e016f21a18163d58c14a12bb78f0a311.xml
#  extracting: train/IMG_4907_JPG.rf.e29fe887b7f6dcd25ba3e34a48857626.jpg
#   inflating: train/IMG_4907_JPG.rf.e29fe887b7f6dcd25ba3e34a48857626.xml
#  extracting: train/IMG_4907_JPG.rf.e2f867b490cbb6b567ba629c633ad459.jpg
#   inflating: train/IMG_4907_JPG.rf.e2f867b490cbb6b567ba629c633ad459.xml
#  extracting: train/IMG_4907_JPG.rf.ec8bb676c0f4062db16bed9956068e95.jpg
#   inflating: train/IMG_4907_JPG.rf.ec8bb676c0f4062db16bed9956068e95.xml
#  extracting: train/IMG_4907_JPG.rf.ed05e29ad6ec27fc4807228f3d3e379d.jpg
#   inflating: train/IMG_4907_JPG.rf.ed05e29ad6ec27fc4807228f3d3e379d.xml
#  extracting: train/IMG_4907_JPG.rf.ef35b5403d0084e12853b75db843a062.jpg
#   inflating: train/IMG_4907_JPG.rf.ef35b5403d0084e12853b75db843a062.xml
#  extracting: train/IMG_4907_JPG.rf.f49082353034b0c64849920bffea7c49.jpg
#   inflating: train/IMG_4907_JPG.rf.f49082353034b0c64849920bffea7c49.xml
#  extracting: train/IMG_4908_JPG.rf.09da96478819de0b49e53332871b593b.jpg
#   inflating: train/IMG_4908_JPG.rf.09da96478819de0b49e53332871b593b.xml
#  extracting: train/IMG_4908_JPG.rf.0e98c5c611891fef27c1f2417c0e4d29.jpg
#   inflating: train/IMG_4908_JPG.rf.0e98c5c611891fef27c1f2417c0e4d29.xml
#  extracting: train/IMG_4908_JPG.rf.10ba8a0756c575d8fce40c3337da2271.jpg
#   inflating: train/IMG_4908_JPG.rf.10ba8a0756c575d8fce40c3337da2271.xml
#  extracting: train/IMG_4908_JPG.rf.1fc8946fa4dd92c6d2da9c4191c77a58.jpg
#   inflating: train/IMG_4908_JPG.rf.1fc8946fa4dd92c6d2da9c4191c77a58.xml
#  extracting: train/IMG_4908_JPG.rf.23b1ce2e1e93f389f68e55be0dcc0729.jpg
#   inflating: train/IMG_4908_JPG.rf.23b1ce2e1e93f389f68e55be0dcc0729.xml
#  extracting: train/IMG_4908_JPG.rf.2bb0d4af5ab74635d10bfba87993de3e.jpg
#   inflating: train/IMG_4908_JPG.rf.2bb0d4af5ab74635d10bfba87993de3e.xml
#  extracting: train/IMG_4908_JPG.rf.341dc5b74e1603924508be82a99c315f.jpg
#   inflating: train/IMG_4908_JPG.rf.341dc5b74e1603924508be82a99c315f.xml
#  extracting: train/IMG_4908_JPG.rf.405188681edf9497e620cbd414f8e9f3.jpg
#   inflating: train/IMG_4908_JPG.rf.405188681edf9497e620cbd414f8e9f3.xml
#  extracting: train/IMG_4908_JPG.rf.409b08cd45d63fa87f3c4b6706cc3ee4.jpg
#   inflating: train/IMG_4908_JPG.rf.409b08cd45d63fa87f3c4b6706cc3ee4.xml
#  extracting: train/IMG_4908_JPG.rf.5699ba1deb3faf30eb00c08e0562f818.jpg
#   inflating: train/IMG_4908_JPG.rf.5699ba1deb3faf30eb00c08e0562f818.xml
#  extracting: train/IMG_4908_JPG.rf.583dbfbeab5d7c39139379a8af84a5a0.jpg
#   inflating: train/IMG_4908_JPG.rf.583dbfbeab5d7c39139379a8af84a5a0.xml
#  extracting: train/IMG_4908_JPG.rf.5f062fb48ea97cfa1d8fbdbd4b2580cd.jpg
#   inflating: train/IMG_4908_JPG.rf.5f062fb48ea97cfa1d8fbdbd4b2580cd.xml
#  extracting: train/IMG_4908_JPG.rf.634cf887f854d1305e7cfa3b947c5234.jpg
#   inflating: train/IMG_4908_JPG.rf.634cf887f854d1305e7cfa3b947c5234.xml
#  extracting: train/IMG_4908_JPG.rf.6f03a94ccdec195bb546b65410de6e70.jpg
#   inflating: train/IMG_4908_JPG.rf.6f03a94ccdec195bb546b65410de6e70.xml
#  extracting: train/IMG_4908_JPG.rf.78112a902ca03a0db1beb6f2d5db9de1.jpg
#   inflating: train/IMG_4908_JPG.rf.78112a902ca03a0db1beb6f2d5db9de1.xml
#  extracting: train/IMG_4908_JPG.rf.86ef417e0393b59b498d686457ff8521.jpg
#   inflating: train/IMG_4908_JPG.rf.86ef417e0393b59b498d686457ff8521.xml
#  extracting: train/IMG_4908_JPG.rf.886f72b7518d371b5c1bc535f364b6c2.jpg
#   inflating: train/IMG_4908_JPG.rf.886f72b7518d371b5c1bc535f364b6c2.xml
#  extracting: train/IMG_4908_JPG.rf.8f81be7ae01be23708749882983d0190.jpg
#   inflating: train/IMG_4908_JPG.rf.8f81be7ae01be23708749882983d0190.xml
#  extracting: train/IMG_4908_JPG.rf.9025f35e496ce7efdf37dd9ad7cb2e5a.jpg
#   inflating: train/IMG_4908_JPG.rf.9025f35e496ce7efdf37dd9ad7cb2e5a.xml
#  extracting: train/IMG_4908_JPG.rf.90389da3af8f85fa9934d5132a44ec10.jpg
#   inflating: train/IMG_4908_JPG.rf.90389da3af8f85fa9934d5132a44ec10.xml
#  extracting: train/IMG_4908_JPG.rf.93e3e0cb00a076c860e68c42f3a2dfdd.jpg
#   inflating: train/IMG_4908_JPG.rf.93e3e0cb00a076c860e68c42f3a2dfdd.xml
#  extracting: train/IMG_4908_JPG.rf.95377f3a918336c91683888e71bffd19.jpg
#   inflating: train/IMG_4908_JPG.rf.95377f3a918336c91683888e71bffd19.xml
#  extracting: train/IMG_4908_JPG.rf.a9aea17b0858867124bd22a2ba6cef3c.jpg
#   inflating: train/IMG_4908_JPG.rf.a9aea17b0858867124bd22a2ba6cef3c.xml
#  extracting: train/IMG_4908_JPG.rf.b079b354a07bc190d3d3d85433917abc.jpg
#   inflating: train/IMG_4908_JPG.rf.b079b354a07bc190d3d3d85433917abc.xml
#  extracting: train/IMG_4908_JPG.rf.b52fdb2eca11cee3b701d6bdcac761e9.jpg
#   inflating: train/IMG_4908_JPG.rf.b52fdb2eca11cee3b701d6bdcac761e9.xml
#  extracting: train/IMG_4908_JPG.rf.b8d0a460e70948436a01f8db4bd8a8de.jpg
#   inflating: train/IMG_4908_JPG.rf.b8d0a460e70948436a01f8db4bd8a8de.xml
#  extracting: train/IMG_4908_JPG.rf.be160eb0c8ff486e62f8986e66e4ffd9.jpg
#   inflating: train/IMG_4908_JPG.rf.be160eb0c8ff486e62f8986e66e4ffd9.xml
#  extracting: train/IMG_4908_JPG.rf.bf572c5393d87606bf8d2fc1131ee044.jpg
#   inflating: train/IMG_4908_JPG.rf.bf572c5393d87606bf8d2fc1131ee044.xml
#  extracting: train/IMG_4908_JPG.rf.c02e216ebbe1bfd833fc7e60dfec33da.jpg
#   inflating: train/IMG_4908_JPG.rf.c02e216ebbe1bfd833fc7e60dfec33da.xml
#  extracting: train/IMG_4908_JPG.rf.c4b0e977977225a08cff3279ddf478d0.jpg
#   inflating: train/IMG_4908_JPG.rf.c4b0e977977225a08cff3279ddf478d0.xml
#  extracting: train/IMG_4908_JPG.rf.c5db57b8033f890f8111ec1c02e5c691.jpg
#   inflating: train/IMG_4908_JPG.rf.c5db57b8033f890f8111ec1c02e5c691.xml
#  extracting: train/IMG_4908_JPG.rf.c7662679bb7f166cd13190b6814f3ed6.jpg
#   inflating: train/IMG_4908_JPG.rf.c7662679bb7f166cd13190b6814f3ed6.xml
#  extracting: train/IMG_4908_JPG.rf.ca09acd92cfac970fab49df6fbd972e9.jpg
#   inflating: train/IMG_4908_JPG.rf.ca09acd92cfac970fab49df6fbd972e9.xml
#  extracting: train/IMG_4908_JPG.rf.caced2b8ca952977682efcf2b1ae67e1.jpg
#   inflating: train/IMG_4908_JPG.rf.caced2b8ca952977682efcf2b1ae67e1.xml
#  extracting: train/IMG_4908_JPG.rf.cbd05a367e6a74243e6748af04dab29f.jpg
#   inflating: train/IMG_4908_JPG.rf.cbd05a367e6a74243e6748af04dab29f.xml
#  extracting: train/IMG_4908_JPG.rf.db0820a6544271d596db772f4c81feb6.jpg
#   inflating: train/IMG_4908_JPG.rf.db0820a6544271d596db772f4c81feb6.xml
#  extracting: train/IMG_4908_JPG.rf.e9b66e6e1c82fb2c2067f5cde3447309.jpg
#   inflating: train/IMG_4908_JPG.rf.e9b66e6e1c82fb2c2067f5cde3447309.xml
#  extracting: train/IMG_4908_JPG.rf.f5480a4946e0af13af5d1e9eb1185df7.jpg
#   inflating: train/IMG_4908_JPG.rf.f5480a4946e0af13af5d1e9eb1185df7.xml
#  extracting: train/IMG_4908_JPG.rf.f82d0f4e7795aed3b19a6883fd0327d0.jpg
#   inflating: train/IMG_4908_JPG.rf.f82d0f4e7795aed3b19a6883fd0327d0.xml
#  extracting: train/IMG_4908_JPG.rf.fbf7101343328a3613b94baa4de926af.jpg
#   inflating: train/IMG_4908_JPG.rf.fbf7101343328a3613b94baa4de926af.xml
#  extracting: train/IMG_4909_JPG.rf.06f6b81defe8496500ae93acb66bdeab.jpg
#   inflating: train/IMG_4909_JPG.rf.06f6b81defe8496500ae93acb66bdeab.xml
#  extracting: train/IMG_4909_JPG.rf.0a45c4b3eb03701f8a788957108aaebe.jpg
#   inflating: train/IMG_4909_JPG.rf.0a45c4b3eb03701f8a788957108aaebe.xml
#  extracting: train/IMG_4909_JPG.rf.0d6d056289372d6c8c94e89817ee03c2.jpg
#   inflating: train/IMG_4909_JPG.rf.0d6d056289372d6c8c94e89817ee03c2.xml
#  extracting: train/IMG_4909_JPG.rf.132696806927efacf852a69ced57ea4a.jpg
#   inflating: train/IMG_4909_JPG.rf.132696806927efacf852a69ced57ea4a.xml
#  extracting: train/IMG_4909_JPG.rf.1429447c36c5e56763ce6393a0dc341f.jpg
#   inflating: train/IMG_4909_JPG.rf.1429447c36c5e56763ce6393a0dc341f.xml
#  extracting: train/IMG_4909_JPG.rf.1c1957875479102fb355044bcfbf464e.jpg
#   inflating: train/IMG_4909_JPG.rf.1c1957875479102fb355044bcfbf464e.xml
#  extracting: train/IMG_4909_JPG.rf.2635222a5aa6161aee3ac5c99ca7b293.jpg
#   inflating: train/IMG_4909_JPG.rf.2635222a5aa6161aee3ac5c99ca7b293.xml
#  extracting: train/IMG_4909_JPG.rf.34a0fd626e036fca10aac92563208713.jpg
#   inflating: train/IMG_4909_JPG.rf.34a0fd626e036fca10aac92563208713.xml
#  extracting: train/IMG_4909_JPG.rf.35d748ac4738480f254b5969d9a12710.jpg
#   inflating: train/IMG_4909_JPG.rf.35d748ac4738480f254b5969d9a12710.xml
#  extracting: train/IMG_4909_JPG.rf.36cc48535609a67ff80e8ca1754c58fb.jpg
#   inflating: train/IMG_4909_JPG.rf.36cc48535609a67ff80e8ca1754c58fb.xml
#  extracting: train/IMG_4909_JPG.rf.377d2e4b8cba6f6ef531fb72b973ebf2.jpg
#   inflating: train/IMG_4909_JPG.rf.377d2e4b8cba6f6ef531fb72b973ebf2.xml
#  extracting: train/IMG_4909_JPG.rf.3cda4b478cd8eb27c17843b7367c39c9.jpg
#   inflating: train/IMG_4909_JPG.rf.3cda4b478cd8eb27c17843b7367c39c9.xml
#  extracting: train/IMG_4909_JPG.rf.42a4c8f6f523fc609e8a971203f5658f.jpg
#   inflating: train/IMG_4909_JPG.rf.42a4c8f6f523fc609e8a971203f5658f.xml
#  extracting: train/IMG_4909_JPG.rf.53f37f8c82fd3e908a19d7bb2745efa8.jpg
#   inflating: train/IMG_4909_JPG.rf.53f37f8c82fd3e908a19d7bb2745efa8.xml
#  extracting: train/IMG_4909_JPG.rf.5cf602b8ce61f0c4e1a022d431924fbc.jpg
#   inflating: train/IMG_4909_JPG.rf.5cf602b8ce61f0c4e1a022d431924fbc.xml
#  extracting: train/IMG_4909_JPG.rf.5ff12de034739752ffc4596816d97d8a.jpg
#   inflating: train/IMG_4909_JPG.rf.5ff12de034739752ffc4596816d97d8a.xml
#  extracting: train/IMG_4909_JPG.rf.78a2a8b7f0fb374b834eb1432b5793b5.jpg
#   inflating: train/IMG_4909_JPG.rf.78a2a8b7f0fb374b834eb1432b5793b5.xml
#  extracting: train/IMG_4909_JPG.rf.87feee280b737daf61fb5eb1db6ffc51.jpg
#   inflating: train/IMG_4909_JPG.rf.87feee280b737daf61fb5eb1db6ffc51.xml
#  extracting: train/IMG_4909_JPG.rf.8b8c8e00e2ea022138c45b85eec32648.jpg
#   inflating: train/IMG_4909_JPG.rf.8b8c8e00e2ea022138c45b85eec32648.xml
#  extracting: train/IMG_4909_JPG.rf.9d51a2af6633bf8e2a1b620fc432ea7d.jpg
#   inflating: train/IMG_4909_JPG.rf.9d51a2af6633bf8e2a1b620fc432ea7d.xml
#  extracting: train/IMG_4909_JPG.rf.9ef6f8038465f05a2ff08dae1d0b0c7d.jpg
#   inflating: train/IMG_4909_JPG.rf.9ef6f8038465f05a2ff08dae1d0b0c7d.xml
#  extracting: train/IMG_4909_JPG.rf.a340e84e1ac68b4bbcd28515c40cd2cd.jpg
#   inflating: train/IMG_4909_JPG.rf.a340e84e1ac68b4bbcd28515c40cd2cd.xml
#  extracting: train/IMG_4909_JPG.rf.a35c2e6845788b2e00004f12513423ef.jpg
#   inflating: train/IMG_4909_JPG.rf.a35c2e6845788b2e00004f12513423ef.xml
#  extracting: train/IMG_4909_JPG.rf.a73f6ed02ab90955dec1d2f977799bdd.jpg
#   inflating: train/IMG_4909_JPG.rf.a73f6ed02ab90955dec1d2f977799bdd.xml
#  extracting: train/IMG_4909_JPG.rf.ab459b1bffa22b1426216808b18bc292.jpg
#   inflating: train/IMG_4909_JPG.rf.ab459b1bffa22b1426216808b18bc292.xml
#  extracting: train/IMG_4909_JPG.rf.adc663fdd127ffc11f6bb5dc3a284874.jpg
#   inflating: train/IMG_4909_JPG.rf.adc663fdd127ffc11f6bb5dc3a284874.xml
#  extracting: train/IMG_4909_JPG.rf.aecf35cc9371be478ed0961a3ec98040.jpg
#   inflating: train/IMG_4909_JPG.rf.aecf35cc9371be478ed0961a3ec98040.xml
#  extracting: train/IMG_4909_JPG.rf.b1a0af2d384901a599e2c43e4da23433.jpg
#   inflating: train/IMG_4909_JPG.rf.b1a0af2d384901a599e2c43e4da23433.xml
#  extracting: train/IMG_4909_JPG.rf.b49c0bc2c62661df2c0ebb639fede02c.jpg
#   inflating: train/IMG_4909_JPG.rf.b49c0bc2c62661df2c0ebb639fede02c.xml
#  extracting: train/IMG_4909_JPG.rf.bd831dba4b1544df8067a374d5682e91.jpg
#   inflating: train/IMG_4909_JPG.rf.bd831dba4b1544df8067a374d5682e91.xml
#  extracting: train/IMG_4909_JPG.rf.cd4aa299889883b3a830ea383813f542.jpg
#   inflating: train/IMG_4909_JPG.rf.cd4aa299889883b3a830ea383813f542.xml
#  extracting: train/IMG_4909_JPG.rf.d9bb37961c6b5c09ac531a18aee30fb4.jpg
#   inflating: train/IMG_4909_JPG.rf.d9bb37961c6b5c09ac531a18aee30fb4.xml
#  extracting: train/IMG_4909_JPG.rf.e2739bb44e82770dc328eb02ece76dac.jpg
#   inflating: train/IMG_4909_JPG.rf.e2739bb44e82770dc328eb02ece76dac.xml
#  extracting: train/IMG_4909_JPG.rf.e6d3198d99426fd73de2e5aad9cae0b0.jpg
#   inflating: train/IMG_4909_JPG.rf.e6d3198d99426fd73de2e5aad9cae0b0.xml
#  extracting: train/IMG_4909_JPG.rf.e91ceea9911581e1972f8db9fa06cf33.jpg
#   inflating: train/IMG_4909_JPG.rf.e91ceea9911581e1972f8db9fa06cf33.xml
#  extracting: train/IMG_4909_JPG.rf.ec3a802d32592def8778d401afb40d57.jpg
#   inflating: train/IMG_4909_JPG.rf.ec3a802d32592def8778d401afb40d57.xml
#  extracting: train/IMG_4909_JPG.rf.f0c96f7d84589312fe7bf5aa4ad00332.jpg
#   inflating: train/IMG_4909_JPG.rf.f0c96f7d84589312fe7bf5aa4ad00332.xml
#  extracting: train/IMG_4909_JPG.rf.f105e5d1338b97804a0210ffb3ea5b92.jpg
#   inflating: train/IMG_4909_JPG.rf.f105e5d1338b97804a0210ffb3ea5b92.xml
#  extracting: train/IMG_4909_JPG.rf.f53156f7b257cd90405513ad3461f15a.jpg
#   inflating: train/IMG_4909_JPG.rf.f53156f7b257cd90405513ad3461f15a.xml
#  extracting: train/IMG_4909_JPG.rf.fb2899732f3dca19ffc7ff660beed04d.jpg
#   inflating: train/IMG_4909_JPG.rf.fb2899732f3dca19ffc7ff660beed04d.xml
#  extracting: train/IMG_4910_JPG.rf.00b3c439d7fdc544d7ae877f5e73c4ca.jpg
#   inflating: train/IMG_4910_JPG.rf.00b3c439d7fdc544d7ae877f5e73c4ca.xml
#  extracting: train/IMG_4910_JPG.rf.0455fc88d6980e62ef12d67d521510de.jpg
#   inflating: train/IMG_4910_JPG.rf.0455fc88d6980e62ef12d67d521510de.xml
#  extracting: train/IMG_4910_JPG.rf.08e9a32dc3ab6fdc3c036d42d0e5a3f2.jpg
#   inflating: train/IMG_4910_JPG.rf.08e9a32dc3ab6fdc3c036d42d0e5a3f2.xml
#  extracting: train/IMG_4910_JPG.rf.14ad89b74ca5f29de51da0d325a7e18d.jpg
#   inflating: train/IMG_4910_JPG.rf.14ad89b74ca5f29de51da0d325a7e18d.xml
#  extracting: train/IMG_4910_JPG.rf.1ba128d5b4556fc4ebfc4a6a4f6ed2d8.jpg
#   inflating: train/IMG_4910_JPG.rf.1ba128d5b4556fc4ebfc4a6a4f6ed2d8.xml
#  extracting: train/IMG_4910_JPG.rf.1ca36dab333ce6ddca0e4604335d42d0.jpg
#   inflating: train/IMG_4910_JPG.rf.1ca36dab333ce6ddca0e4604335d42d0.xml
#  extracting: train/IMG_4910_JPG.rf.4fe1a72b578fe171b8dd910fcbf3484d.jpg
#   inflating: train/IMG_4910_JPG.rf.4fe1a72b578fe171b8dd910fcbf3484d.xml
#  extracting: train/IMG_4910_JPG.rf.5e154c87b94d0c2334644b4f219a4b55.jpg
#   inflating: train/IMG_4910_JPG.rf.5e154c87b94d0c2334644b4f219a4b55.xml
#  extracting: train/IMG_4910_JPG.rf.5e3ec8a938d82c3a74a67d62e8447f8c.jpg
#   inflating: train/IMG_4910_JPG.rf.5e3ec8a938d82c3a74a67d62e8447f8c.xml
#  extracting: train/IMG_4910_JPG.rf.62ed04d1d4ba8082b3e5941ae46c8cfd.jpg
#   inflating: train/IMG_4910_JPG.rf.62ed04d1d4ba8082b3e5941ae46c8cfd.xml
#  extracting: train/IMG_4910_JPG.rf.6c4c472d229f507652f73dae14c612b9.jpg
#   inflating: train/IMG_4910_JPG.rf.6c4c472d229f507652f73dae14c612b9.xml
#  extracting: train/IMG_4910_JPG.rf.7021e48e13c0c02cfa891692cadd21c2.jpg
#   inflating: train/IMG_4910_JPG.rf.7021e48e13c0c02cfa891692cadd21c2.xml
#  extracting: train/IMG_4910_JPG.rf.72b87419ab4a8482736d1b4c2148a6f3.jpg
#   inflating: train/IMG_4910_JPG.rf.72b87419ab4a8482736d1b4c2148a6f3.xml
#  extracting: train/IMG_4910_JPG.rf.742478f90bd3d9b683a41aed915795b5.jpg
#   inflating: train/IMG_4910_JPG.rf.742478f90bd3d9b683a41aed915795b5.xml
#  extracting: train/IMG_4910_JPG.rf.77f64016c4d67b3fb4ddc73e077e7b9b.jpg
#   inflating: train/IMG_4910_JPG.rf.77f64016c4d67b3fb4ddc73e077e7b9b.xml
#  extracting: train/IMG_4910_JPG.rf.7a401e4d0d11b36031c89537b13e3d15.jpg
#   inflating: train/IMG_4910_JPG.rf.7a401e4d0d11b36031c89537b13e3d15.xml
#  extracting: train/IMG_4910_JPG.rf.7c13a1efc4ffc574c6cc701b322491e0.jpg
#   inflating: train/IMG_4910_JPG.rf.7c13a1efc4ffc574c6cc701b322491e0.xml
#  extracting: train/IMG_4910_JPG.rf.854bc2cdd8e90617fc2591309522d57b.jpg
#   inflating: train/IMG_4910_JPG.rf.854bc2cdd8e90617fc2591309522d57b.xml
#  extracting: train/IMG_4910_JPG.rf.859565a31730180dafa9735bfc144e61.jpg
#   inflating: train/IMG_4910_JPG.rf.859565a31730180dafa9735bfc144e61.xml
#  extracting: train/IMG_4910_JPG.rf.9c4a14f5a548ca805d7d66bccc38d17b.jpg
#   inflating: train/IMG_4910_JPG.rf.9c4a14f5a548ca805d7d66bccc38d17b.xml
#  extracting: train/IMG_4910_JPG.rf.a031982a496b4227937f60b12cb9e7e3.jpg
#   inflating: train/IMG_4910_JPG.rf.a031982a496b4227937f60b12cb9e7e3.xml
#  extracting: train/IMG_4910_JPG.rf.a15d95e61350b6181c3bd91d77e6211f.jpg
#   inflating: train/IMG_4910_JPG.rf.a15d95e61350b6181c3bd91d77e6211f.xml
#  extracting: train/IMG_4910_JPG.rf.a83561a074e161b26352b28f36a00865.jpg
#   inflating: train/IMG_4910_JPG.rf.a83561a074e161b26352b28f36a00865.xml
#  extracting: train/IMG_4910_JPG.rf.a91e5bcd9bcfa4238cc45d6eb2cf69f1.jpg
#   inflating: train/IMG_4910_JPG.rf.a91e5bcd9bcfa4238cc45d6eb2cf69f1.xml
#  extracting: train/IMG_4910_JPG.rf.aca7b7331a4eecb13e083eb9260d303d.jpg
#   inflating: train/IMG_4910_JPG.rf.aca7b7331a4eecb13e083eb9260d303d.xml
#  extracting: train/IMG_4910_JPG.rf.b3ee1a766a4359bba96cf7cfc7b38d57.jpg
#   inflating: train/IMG_4910_JPG.rf.b3ee1a766a4359bba96cf7cfc7b38d57.xml
#  extracting: train/IMG_4910_JPG.rf.bae7eded5ecdf5ae931afe10a74f57f3.jpg
#   inflating: train/IMG_4910_JPG.rf.bae7eded5ecdf5ae931afe10a74f57f3.xml
#  extracting: train/IMG_4910_JPG.rf.bfa3e60809613522285e38f7dd89811d.jpg
#   inflating: train/IMG_4910_JPG.rf.bfa3e60809613522285e38f7dd89811d.xml
#  extracting: train/IMG_4910_JPG.rf.c0fdb95f69d1ce55b74e348b338be918.jpg
#   inflating: train/IMG_4910_JPG.rf.c0fdb95f69d1ce55b74e348b338be918.xml
#  extracting: train/IMG_4910_JPG.rf.c20e345a14ad45e072e2bb965b6d9d0c.jpg
#   inflating: train/IMG_4910_JPG.rf.c20e345a14ad45e072e2bb965b6d9d0c.xml
#  extracting: train/IMG_4910_JPG.rf.ce31e764f4dc8b56d84775477bb48c3a.jpg
#   inflating: train/IMG_4910_JPG.rf.ce31e764f4dc8b56d84775477bb48c3a.xml
#  extracting: train/IMG_4910_JPG.rf.d944edb8c195e6c86d9d599d0c81d4ec.jpg
#   inflating: train/IMG_4910_JPG.rf.d944edb8c195e6c86d9d599d0c81d4ec.xml
#  extracting: train/IMG_4910_JPG.rf.da4b37c806c1e7dc6ecbae31ac88028b.jpg
#   inflating: train/IMG_4910_JPG.rf.da4b37c806c1e7dc6ecbae31ac88028b.xml
#  extracting: train/IMG_4910_JPG.rf.dca2ab7b602ac65281fec5e95ad7fb03.jpg
#   inflating: train/IMG_4910_JPG.rf.dca2ab7b602ac65281fec5e95ad7fb03.xml
#  extracting: train/IMG_4910_JPG.rf.e53629ee3d5b30dec52b0c7ba101063f.jpg
#   inflating: train/IMG_4910_JPG.rf.e53629ee3d5b30dec52b0c7ba101063f.xml
#  extracting: train/IMG_4910_JPG.rf.eab82f792d7b5f5c43fbd8ab347831ae.jpg
#   inflating: train/IMG_4910_JPG.rf.eab82f792d7b5f5c43fbd8ab347831ae.xml
#  extracting: train/IMG_4910_JPG.rf.ef74d76a2ccc7789fb2a0c70af851c58.jpg
#   inflating: train/IMG_4910_JPG.rf.ef74d76a2ccc7789fb2a0c70af851c58.xml
#  extracting: train/IMG_4910_JPG.rf.efe7bb6af981fc8ed195ea8306e57fef.jpg
#   inflating: train/IMG_4910_JPG.rf.efe7bb6af981fc8ed195ea8306e57fef.xml
#  extracting: train/IMG_4910_JPG.rf.faab7f7b9a91a60d98bd157fcddeabd6.jpg
#   inflating: train/IMG_4910_JPG.rf.faab7f7b9a91a60d98bd157fcddeabd6.xml
#  extracting: train/IMG_4910_JPG.rf.ff3b6e066cf9be32fb1eecb23ea61ca6.jpg
#   inflating: train/IMG_4910_JPG.rf.ff3b6e066cf9be32fb1eecb23ea61ca6.xml
#  extracting: train/IMG_4911_JPG.rf.0cad2f292a173cf472263536ba409613.jpg
#   inflating: train/IMG_4911_JPG.rf.0cad2f292a173cf472263536ba409613.xml
#  extracting: train/IMG_4911_JPG.rf.0f53791a0f59d938abef3f6e0c8564a7.jpg
#   inflating: train/IMG_4911_JPG.rf.0f53791a0f59d938abef3f6e0c8564a7.xml
#  extracting: train/IMG_4911_JPG.rf.12dd008fd285ec2bdbc5468c69f7ce33.jpg
#   inflating: train/IMG_4911_JPG.rf.12dd008fd285ec2bdbc5468c69f7ce33.xml
#  extracting: train/IMG_4911_JPG.rf.1684c536bd21373e8eb55fdbd824fe9e.jpg
#   inflating: train/IMG_4911_JPG.rf.1684c536bd21373e8eb55fdbd824fe9e.xml
#  extracting: train/IMG_4911_JPG.rf.17185254590ae11f5d7708b2a5c0ee6c.jpg
#   inflating: train/IMG_4911_JPG.rf.17185254590ae11f5d7708b2a5c0ee6c.xml
#  extracting: train/IMG_4911_JPG.rf.1d8bf9b1cc7f9bcb6a17606c7c6ae990.jpg
#   inflating: train/IMG_4911_JPG.rf.1d8bf9b1cc7f9bcb6a17606c7c6ae990.xml
#  extracting: train/IMG_4911_JPG.rf.263d8ee44cb3374a2ccdc83238cd2e4d.jpg
#   inflating: train/IMG_4911_JPG.rf.263d8ee44cb3374a2ccdc83238cd2e4d.xml
#  extracting: train/IMG_4911_JPG.rf.277de46846c4af269a967d16420692d8.jpg
#   inflating: train/IMG_4911_JPG.rf.277de46846c4af269a967d16420692d8.xml
#  extracting: train/IMG_4911_JPG.rf.2d9aba79f3d2ff299bce83543474a30b.jpg
#   inflating: train/IMG_4911_JPG.rf.2d9aba79f3d2ff299bce83543474a30b.xml
#  extracting: train/IMG_4911_JPG.rf.2e22c73d35d2d49b97e9dd51ab146282.jpg
#   inflating: train/IMG_4911_JPG.rf.2e22c73d35d2d49b97e9dd51ab146282.xml
#  extracting: train/IMG_4911_JPG.rf.30e9a3c467594ed3b391df8c12349a79.jpg
#   inflating: train/IMG_4911_JPG.rf.30e9a3c467594ed3b391df8c12349a79.xml
#  extracting: train/IMG_4911_JPG.rf.3248b0d68dbdb6c3d104833d65d6403a.jpg
#   inflating: train/IMG_4911_JPG.rf.3248b0d68dbdb6c3d104833d65d6403a.xml
#  extracting: train/IMG_4911_JPG.rf.411dc41ec662e37fc6ef61b7a96f5fed.jpg
#   inflating: train/IMG_4911_JPG.rf.411dc41ec662e37fc6ef61b7a96f5fed.xml
#  extracting: train/IMG_4911_JPG.rf.428bc5b8857613f85a944d40900f13fc.jpg
#   inflating: train/IMG_4911_JPG.rf.428bc5b8857613f85a944d40900f13fc.xml
#  extracting: train/IMG_4911_JPG.rf.478854497b8cab2ac5dab5e992b40bcc.jpg
#   inflating: train/IMG_4911_JPG.rf.478854497b8cab2ac5dab5e992b40bcc.xml
#  extracting: train/IMG_4911_JPG.rf.4d7c749a7c99c2fad1d847b440975588.jpg
#   inflating: train/IMG_4911_JPG.rf.4d7c749a7c99c2fad1d847b440975588.xml
#  extracting: train/IMG_4911_JPG.rf.4dcb846e1205253e00d939f503915c88.jpg
#   inflating: train/IMG_4911_JPG.rf.4dcb846e1205253e00d939f503915c88.xml
#  extracting: train/IMG_4911_JPG.rf.538d99a5f2844ed80839f536df18444a.jpg
#   inflating: train/IMG_4911_JPG.rf.538d99a5f2844ed80839f536df18444a.xml
#  extracting: train/IMG_4911_JPG.rf.7a672964f7c92e337ffbdbb7623b916e.jpg
#   inflating: train/IMG_4911_JPG.rf.7a672964f7c92e337ffbdbb7623b916e.xml
#  extracting: train/IMG_4911_JPG.rf.820cac237f86753e450bbdbf68073d93.jpg
#   inflating: train/IMG_4911_JPG.rf.820cac237f86753e450bbdbf68073d93.xml
#  extracting: train/IMG_4911_JPG.rf.876a0acb46a2decb647e252fbc2a50e0.jpg
#   inflating: train/IMG_4911_JPG.rf.876a0acb46a2decb647e252fbc2a50e0.xml
#  extracting: train/IMG_4911_JPG.rf.8b7fa692626fbc85bfb6548709b593d1.jpg
#   inflating: train/IMG_4911_JPG.rf.8b7fa692626fbc85bfb6548709b593d1.xml
#  extracting: train/IMG_4911_JPG.rf.92f35771b029e5a4e3e71c3f77e41301.jpg
#   inflating: train/IMG_4911_JPG.rf.92f35771b029e5a4e3e71c3f77e41301.xml
#  extracting: train/IMG_4911_JPG.rf.984e0da2f106b7f8c930c3aee0a4ace8.jpg
#   inflating: train/IMG_4911_JPG.rf.984e0da2f106b7f8c930c3aee0a4ace8.xml
#  extracting: train/IMG_4911_JPG.rf.9da7d8d0c3f12292e868b31f29ad06d7.jpg
#   inflating: train/IMG_4911_JPG.rf.9da7d8d0c3f12292e868b31f29ad06d7.xml
#  extracting: train/IMG_4911_JPG.rf.9f7cf5c3bb7f8432d4712280bf2bd6c4.jpg
#   inflating: train/IMG_4911_JPG.rf.9f7cf5c3bb7f8432d4712280bf2bd6c4.xml
#  extracting: train/IMG_4911_JPG.rf.a01ecf69e99ea084ec6e6c331fd7c796.jpg
#   inflating: train/IMG_4911_JPG.rf.a01ecf69e99ea084ec6e6c331fd7c796.xml
#  extracting: train/IMG_4911_JPG.rf.a8dfe4470a496ee5a0a51e5ec2ec3103.jpg
#   inflating: train/IMG_4911_JPG.rf.a8dfe4470a496ee5a0a51e5ec2ec3103.xml
#  extracting: train/IMG_4911_JPG.rf.adbc659428191d69b82a19c7203c77a0.jpg
#   inflating: train/IMG_4911_JPG.rf.adbc659428191d69b82a19c7203c77a0.xml
#  extracting: train/IMG_4911_JPG.rf.b0e821e25de87584ac052dcb451723f2.jpg
#   inflating: train/IMG_4911_JPG.rf.b0e821e25de87584ac052dcb451723f2.xml
#  extracting: train/IMG_4911_JPG.rf.b8a52da461ca7577efa8d3f3121a6a1f.jpg
#   inflating: train/IMG_4911_JPG.rf.b8a52da461ca7577efa8d3f3121a6a1f.xml
#  extracting: train/IMG_4911_JPG.rf.b9c3ce44434dc3edab32588d563eb981.jpg
#   inflating: train/IMG_4911_JPG.rf.b9c3ce44434dc3edab32588d563eb981.xml
#  extracting: train/IMG_4911_JPG.rf.c18f24175e488034ef6e4148f1fa5aa7.jpg
#   inflating: train/IMG_4911_JPG.rf.c18f24175e488034ef6e4148f1fa5aa7.xml
#  extracting: train/IMG_4911_JPG.rf.d0cdaf2faedd3b5f0591fef77237400f.jpg
#   inflating: train/IMG_4911_JPG.rf.d0cdaf2faedd3b5f0591fef77237400f.xml
#  extracting: train/IMG_4911_JPG.rf.d1c32fe08c34d33dc7b0261ab87de096.jpg
#   inflating: train/IMG_4911_JPG.rf.d1c32fe08c34d33dc7b0261ab87de096.xml
#  extracting: train/IMG_4911_JPG.rf.e4f9823b478d3b23a299e259b1d1fa95.jpg
#   inflating: train/IMG_4911_JPG.rf.e4f9823b478d3b23a299e259b1d1fa95.xml
#  extracting: train/IMG_4911_JPG.rf.e6f5d1b97d9765d4e8570ef0f8ee2ace.jpg
#   inflating: train/IMG_4911_JPG.rf.e6f5d1b97d9765d4e8570ef0f8ee2ace.xml
#  extracting: train/IMG_4911_JPG.rf.f47f63e2a17c59e2729ba8bec14fcce3.jpg
#   inflating: train/IMG_4911_JPG.rf.f47f63e2a17c59e2729ba8bec14fcce3.xml
#  extracting: train/IMG_4911_JPG.rf.f6c7e8911ff015c164d498ad887ef78e.jpg
#   inflating: train/IMG_4911_JPG.rf.f6c7e8911ff015c164d498ad887ef78e.xml
#  extracting: train/IMG_4911_JPG.rf.f74eb543fbc582fa841934f849059b7b.jpg
#   inflating: train/IMG_4911_JPG.rf.f74eb543fbc582fa841934f849059b7b.xml
#  extracting: train/IMG_4912_JPG.rf.01f1b6a9511b5b87f92defb4412008aa.jpg
#   inflating: train/IMG_4912_JPG.rf.01f1b6a9511b5b87f92defb4412008aa.xml
#  extracting: train/IMG_4912_JPG.rf.0dcf5f8ac5d7b3f742993a786cef231f.jpg
#   inflating: train/IMG_4912_JPG.rf.0dcf5f8ac5d7b3f742993a786cef231f.xml
#  extracting: train/IMG_4912_JPG.rf.0e880579bc27595fdfb0a896878e5c98.jpg
#   inflating: train/IMG_4912_JPG.rf.0e880579bc27595fdfb0a896878e5c98.xml
#  extracting: train/IMG_4912_JPG.rf.1866864f6e8a67552e3fe260e427da40.jpg
#   inflating: train/IMG_4912_JPG.rf.1866864f6e8a67552e3fe260e427da40.xml
#  extracting: train/IMG_4912_JPG.rf.1e071fcb57964c7a1a3962a73e6ce0aa.jpg
#   inflating: train/IMG_4912_JPG.rf.1e071fcb57964c7a1a3962a73e6ce0aa.xml
#  extracting: train/IMG_4912_JPG.rf.1e630ddf713b548fc7c9eba247995887.jpg
#   inflating: train/IMG_4912_JPG.rf.1e630ddf713b548fc7c9eba247995887.xml
#  extracting: train/IMG_4912_JPG.rf.1f1957b04b087da0f5a2a35b651a85b1.jpg
#   inflating: train/IMG_4912_JPG.rf.1f1957b04b087da0f5a2a35b651a85b1.xml
#  extracting: train/IMG_4912_JPG.rf.208c6e7e8a1bd8ac5aabaf1ca6fad660.jpg
#   inflating: train/IMG_4912_JPG.rf.208c6e7e8a1bd8ac5aabaf1ca6fad660.xml
#  extracting: train/IMG_4912_JPG.rf.22621c50f4871df74c4d6958bc6cac00.jpg
#   inflating: train/IMG_4912_JPG.rf.22621c50f4871df74c4d6958bc6cac00.xml
#  extracting: train/IMG_4912_JPG.rf.27e17a93a8ebabbc6aa34ba3fdfb32c1.jpg
#   inflating: train/IMG_4912_JPG.rf.27e17a93a8ebabbc6aa34ba3fdfb32c1.xml
#  extracting: train/IMG_4912_JPG.rf.2da8165b9a1e301264b0d4e92c86e7c9.jpg
#   inflating: train/IMG_4912_JPG.rf.2da8165b9a1e301264b0d4e92c86e7c9.xml
#  extracting: train/IMG_4912_JPG.rf.305256cd371f24b22e920b0256a86474.jpg
#   inflating: train/IMG_4912_JPG.rf.305256cd371f24b22e920b0256a86474.xml
#  extracting: train/IMG_4912_JPG.rf.3add8af058a0fc7ab68b489c9bf423f6.jpg
#   inflating: train/IMG_4912_JPG.rf.3add8af058a0fc7ab68b489c9bf423f6.xml
#  extracting: train/IMG_4912_JPG.rf.3f4d7820171f5d156b2cc1920dc2e52c.jpg
#   inflating: train/IMG_4912_JPG.rf.3f4d7820171f5d156b2cc1920dc2e52c.xml
#  extracting: train/IMG_4912_JPG.rf.4254228c3a2f2d2432684f6ea9358d65.jpg
#   inflating: train/IMG_4912_JPG.rf.4254228c3a2f2d2432684f6ea9358d65.xml
#  extracting: train/IMG_4912_JPG.rf.4fe2634f635274947db42815a3f3bb18.jpg
#   inflating: train/IMG_4912_JPG.rf.4fe2634f635274947db42815a3f3bb18.xml
#  extracting: train/IMG_4912_JPG.rf.60ae679724fb139c41a6e44ca294c7b2.jpg
#   inflating: train/IMG_4912_JPG.rf.60ae679724fb139c41a6e44ca294c7b2.xml
#  extracting: train/IMG_4912_JPG.rf.628f11a35c1467d6eccb898da5f6fba5.jpg
#   inflating: train/IMG_4912_JPG.rf.628f11a35c1467d6eccb898da5f6fba5.xml
#  extracting: train/IMG_4912_JPG.rf.6386cb72bb46ef2fe630c8d1b8eca138.jpg
#   inflating: train/IMG_4912_JPG.rf.6386cb72bb46ef2fe630c8d1b8eca138.xml
#  extracting: train/IMG_4912_JPG.rf.7166cbce038eafc6704febe342321838.jpg
#   inflating: train/IMG_4912_JPG.rf.7166cbce038eafc6704febe342321838.xml
#  extracting: train/IMG_4912_JPG.rf.756f4854fd44d4d14f7573311769559e.jpg
#   inflating: train/IMG_4912_JPG.rf.756f4854fd44d4d14f7573311769559e.xml
#  extracting: train/IMG_4912_JPG.rf.75da25350521d2761e8cdf9052072dfa.jpg
#   inflating: train/IMG_4912_JPG.rf.75da25350521d2761e8cdf9052072dfa.xml
#  extracting: train/IMG_4912_JPG.rf.88ddd68e9b11c2bbbfba583d59c0027f.jpg
#   inflating: train/IMG_4912_JPG.rf.88ddd68e9b11c2bbbfba583d59c0027f.xml
#  extracting: train/IMG_4912_JPG.rf.8976d41afd0619ab806fe3f6838fc4ab.jpg
#   inflating: train/IMG_4912_JPG.rf.8976d41afd0619ab806fe3f6838fc4ab.xml
#  extracting: train/IMG_4912_JPG.rf.8b2d6397aa09d51b87f7d2b6cf028164.jpg
#   inflating: train/IMG_4912_JPG.rf.8b2d6397aa09d51b87f7d2b6cf028164.xml
#  extracting: train/IMG_4912_JPG.rf.8c6d41ea107f83f4a1f28e9f8fa6b52c.jpg
#   inflating: train/IMG_4912_JPG.rf.8c6d41ea107f83f4a1f28e9f8fa6b52c.xml
#  extracting: train/IMG_4912_JPG.rf.91d2bdf4e884ce62999e06e2f4acd100.jpg
#   inflating: train/IMG_4912_JPG.rf.91d2bdf4e884ce62999e06e2f4acd100.xml
#  extracting: train/IMG_4912_JPG.rf.92d3933fec04b468088b680143ea025e.jpg
#   inflating: train/IMG_4912_JPG.rf.92d3933fec04b468088b680143ea025e.xml
#  extracting: train/IMG_4912_JPG.rf.9b257551c419e7e03b8296d53338f4d1.jpg
#   inflating: train/IMG_4912_JPG.rf.9b257551c419e7e03b8296d53338f4d1.xml
#  extracting: train/IMG_4912_JPG.rf.9ee3e4ae4ad5a11d1d454e951f17e3b6.jpg
#   inflating: train/IMG_4912_JPG.rf.9ee3e4ae4ad5a11d1d454e951f17e3b6.xml
#  extracting: train/IMG_4912_JPG.rf.9f03a6fce8deef0260da31996d5b06e4.jpg
#   inflating: train/IMG_4912_JPG.rf.9f03a6fce8deef0260da31996d5b06e4.xml
#  extracting: train/IMG_4912_JPG.rf.a7fa675a95764e0cc9888a7596971645.jpg
#   inflating: train/IMG_4912_JPG.rf.a7fa675a95764e0cc9888a7596971645.xml
#  extracting: train/IMG_4912_JPG.rf.a8eeb645d2f8399c3e42f411ce4505af.jpg
#   inflating: train/IMG_4912_JPG.rf.a8eeb645d2f8399c3e42f411ce4505af.xml
#  extracting: train/IMG_4912_JPG.rf.bc03d6d1740298993c3b155f6ebf664b.jpg
#   inflating: train/IMG_4912_JPG.rf.bc03d6d1740298993c3b155f6ebf664b.xml
#  extracting: train/IMG_4912_JPG.rf.db643fe27fb6416de6b397a93a4a173b.jpg
#   inflating: train/IMG_4912_JPG.rf.db643fe27fb6416de6b397a93a4a173b.xml
#  extracting: train/IMG_4912_JPG.rf.e42e302b9a1b70f48d2d4f7f12aa1d0f.jpg
#   inflating: train/IMG_4912_JPG.rf.e42e302b9a1b70f48d2d4f7f12aa1d0f.xml
#  extracting: train/IMG_4912_JPG.rf.e988442a064af83c8225eb6f937f697c.jpg
#   inflating: train/IMG_4912_JPG.rf.e988442a064af83c8225eb6f937f697c.xml
#  extracting: train/IMG_4912_JPG.rf.ea4962a1c092281da0f902e3e71261f7.jpg
#   inflating: train/IMG_4912_JPG.rf.ea4962a1c092281da0f902e3e71261f7.xml
#  extracting: train/IMG_4912_JPG.rf.f518053b85a0287504facd0a83a45b12.jpg
#   inflating: train/IMG_4912_JPG.rf.f518053b85a0287504facd0a83a45b12.xml
#  extracting: train/IMG_4912_JPG.rf.f792bb55ecfcade45236081699d30792.jpg
#   inflating: train/IMG_4912_JPG.rf.f792bb55ecfcade45236081699d30792.xml
#  extracting: train/IMG_4913_JPG.rf.160add163d5b59f3891e19ba5940ddbd.jpg
#   inflating: train/IMG_4913_JPG.rf.160add163d5b59f3891e19ba5940ddbd.xml
#  extracting: train/IMG_4913_JPG.rf.16219186fffc7caa6ea22e9326eb6814.jpg
#   inflating: train/IMG_4913_JPG.rf.16219186fffc7caa6ea22e9326eb6814.xml
#  extracting: train/IMG_4913_JPG.rf.1cefce02f0396ba17e22c9d94746925e.jpg
#   inflating: train/IMG_4913_JPG.rf.1cefce02f0396ba17e22c9d94746925e.xml
#  extracting: train/IMG_4913_JPG.rf.2844303c1723b09afffeb6f695365a3c.jpg
#   inflating: train/IMG_4913_JPG.rf.2844303c1723b09afffeb6f695365a3c.xml
#  extracting: train/IMG_4913_JPG.rf.2e579e3e3fb8b9620a9acca00018b7c9.jpg
#   inflating: train/IMG_4913_JPG.rf.2e579e3e3fb8b9620a9acca00018b7c9.xml
#  extracting: train/IMG_4913_JPG.rf.32f8b99b2879ad6d95b8cf053f36dabc.jpg
#   inflating: train/IMG_4913_JPG.rf.32f8b99b2879ad6d95b8cf053f36dabc.xml
#  extracting: train/IMG_4913_JPG.rf.35663876a6161e739cd6d25e52c99a41.jpg
#   inflating: train/IMG_4913_JPG.rf.35663876a6161e739cd6d25e52c99a41.xml
#  extracting: train/IMG_4913_JPG.rf.3aa8a83ba02c0f367ef1e9e33f8f5d05.jpg
# ...
#  extracting: train/IMG_4964_JPG.rf.3e25e8ddbd683273d62b614b775086a6.jpg
#   inflating: train/IMG_4964_JPG.rf.3e25e8ddbd683273d62b614b775086a6.xml
#  extracting: train/IMG_4964_JPG.rf.49916a3abdc3df431f4154055a7155e6.jpg
#   inflating: train/IMG_4964_JPG.rf.49916a3abdc3df431f4154055a7155e6.xml
#  extracting: train/IMG_4964_JPG.rf.4bcfb84f0ec3363da1d16884cb428ae3.jpg
#   inflating: train/IMG_4964_JPG.rf.4bcfb84f0ec3363da1d16884cb428ae3.xml
#  extracting: train/IMG_4964_JPG.rf.50e674c88221db7c224e5a04fa3e490c.jpg
#   inflating: train/IMG_4964_JPG.rf.50e674c88221db7c224e5a04fa3e490c.xml
#  extracting: train/IMG_4964_JPG.rf.54b378756cfcb824f16cb36934dee15b.jpg
#   inflating: train/IMG_4964_JPG.rf.54b378756cfcb824f16cb36934dee15b.xml
#  extracting: train/IMG_4964_JPG.rf.59ba602926cd76d823bbf70a710a27b9.jpg
#   inflating: train/IMG_4964_JPG.rf.59ba602926cd76d823bbf70a710a27b9.xml
#  extracting: train/IMG_4964_JPG.rf.5bf1c321d4b2297106132516ffb9a7e8.jpg
#   inflating: train/IMG_4964_JPG.rf.5bf1c321d4b2297106132516ffb9a7e8.xml
#  extracting: train/IMG_4964_JPG.rf.61b1eb67a6908690837f68f4661e80c8.jpg
#   inflating: train/IMG_4964_JPG.rf.61b1eb67a6908690837f68f4661e80c8.xml
#  extracting: train/IMG_4964_JPG.rf.6458086170f81a8c1ea9f5f203fb0cc1.jpg
#   inflating: train/IMG_4964_JPG.rf.6458086170f81a8c1ea9f5f203fb0cc1.xml
#  extracting: train/IMG_4964_JPG.rf.6470dacd25b363aae84a5aecc0e29f06.jpg
#   inflating: train/IMG_4964_JPG.rf.6470dacd25b363aae84a5aecc0e29f06.xml
#  extracting: train/IMG_4964_JPG.rf.6508cee1fc1f1f104040dfe05a9b56da.jpg
#   inflating: train/IMG_4964_JPG.rf.6508cee1fc1f1f104040dfe05a9b56da.xml
#  extracting: train/IMG_4964_JPG.rf.774587f07052f7cc3578aa942ccaf13d.jpg
#   inflating: train/IMG_4964_JPG.rf.774587f07052f7cc3578aa942ccaf13d.xml
#  extracting: train/IMG_4964_JPG.rf.78f578fa1d9111a2970e79741b4eb3f4.jpg
#   inflating: train/IMG_4964_JPG.rf.78f578fa1d9111a2970e79741b4eb3f4.xml
#  extracting: train/IMG_4964_JPG.rf.7969fcc9bfc42449959729026280e157.jpg
#   inflating: train/IMG_4964_JPG.rf.7969fcc9bfc42449959729026280e157.xml
#  extracting: train/IMG_4964_JPG.rf.79ccb71b5ea246141e2d5b2d9198b699.jpg
#   inflating: train/IMG_4964_JPG.rf.79ccb71b5ea246141e2d5b2d9198b699.xml
#  extracting: train/IMG_4964_JPG.rf.7aee7a5512eea6a3028f2679169b335b.jpg
#   inflating: train/IMG_4964_JPG.rf.7aee7a5512eea6a3028f2679169b335b.xml
#  extracting: train/IMG_4964_JPG.rf.7d4b070f7a56aab68469c790afd0ebcc.jpg
#   inflating: train/IMG_4964_JPG.rf.7d4b070f7a56aab68469c790afd0ebcc.xml
#  extracting: train/IMG_4964_JPG.rf.8200fc53b40320bf707fcfcf6aa73b96.jpg
#   inflating: train/IMG_4964_JPG.rf.8200fc53b40320bf707fcfcf6aa73b96.xml
#  extracting: train/IMG_4964_JPG.rf.8439a87562f700f2a9f78431ec9befce.jpg
#   inflating: train/IMG_4964_JPG.rf.8439a87562f700f2a9f78431ec9befce.xml
#  extracting: train/IMG_4964_JPG.rf.9b72f81ba9bfbf28a8d0eeca04105206.jpg
#   inflating: train/IMG_4964_JPG.rf.9b72f81ba9bfbf28a8d0eeca04105206.xml
#  extracting: train/IMG_4964_JPG.rf.9d23815be8b962f3354cb1e5c0a58b2e.jpg
#   inflating: train/IMG_4964_JPG.rf.9d23815be8b962f3354cb1e5c0a58b2e.xml
#  extracting: train/IMG_4964_JPG.rf.9f1dbd41c5ae0012cffbdb634880694a.jpg
#   inflating: train/IMG_4964_JPG.rf.9f1dbd41c5ae0012cffbdb634880694a.xml
#  extracting: train/IMG_4964_JPG.rf.a13ec4a6245c53119f83b7a2974a843f.jpg
#   inflating: train/IMG_4964_JPG.rf.a13ec4a6245c53119f83b7a2974a843f.xml
#  extracting: train/IMG_4964_JPG.rf.b3adbfb8b668dd922244b8fae6b731d1.jpg
#   inflating: train/IMG_4964_JPG.rf.b3adbfb8b668dd922244b8fae6b731d1.xml
#  extracting: train/IMG_4964_JPG.rf.b984ea745ca66dee30706f0e020aae05.jpg
#   inflating: train/IMG_4964_JPG.rf.b984ea745ca66dee30706f0e020aae05.xml
#  extracting: train/IMG_4964_JPG.rf.ba47a6b0a98f5717526faed593a1cc19.jpg
#   inflating: train/IMG_4964_JPG.rf.ba47a6b0a98f5717526faed593a1cc19.xml
#  extracting: train/IMG_4964_JPG.rf.ccbd2001d27a09cdb773e04493da298d.jpg
#   inflating: train/IMG_4964_JPG.rf.ccbd2001d27a09cdb773e04493da298d.xml
#  extracting: train/IMG_4964_JPG.rf.db5ed5f01a389ebfb1e3dd4a3e592f0b.jpg
#   inflating: train/IMG_4964_JPG.rf.db5ed5f01a389ebfb1e3dd4a3e592f0b.xml
#  extracting: train/IMG_4965_JPG.rf.188931fba6cea640b9c1f47263d75d2c.jpg
#   inflating: train/IMG_4965_JPG.rf.188931fba6cea640b9c1f47263d75d2c.xml
#  extracting: train/IMG_4965_JPG.rf.1ab1ac26cd50f12a0a624636f50ac65c.jpg
#   inflating: train/IMG_4965_JPG.rf.1ab1ac26cd50f12a0a624636f50ac65c.xml
#  extracting: train/IMG_4965_JPG.rf.21d6d3baa6e96280511c3d7757f80598.jpg
#   inflating: train/IMG_4965_JPG.rf.21d6d3baa6e96280511c3d7757f80598.xml
#  extracting: train/IMG_4965_JPG.rf.2209f080183509e26803df647185cddc.jpg
#   inflating: train/IMG_4965_JPG.rf.2209f080183509e26803df647185cddc.xml
#  extracting: train/IMG_4965_JPG.rf.292981a3227752717748a26425402864.jpg
#   inflating: train/IMG_4965_JPG.rf.292981a3227752717748a26425402864.xml
#  extracting: train/IMG_4965_JPG.rf.344fff72931229ef42cdb99b760f8070.jpg
#   inflating: train/IMG_4965_JPG.rf.344fff72931229ef42cdb99b760f8070.xml
#  extracting: train/IMG_4965_JPG.rf.34c25bed949954d12bb79b4b23398332.jpg
#   inflating: train/IMG_4965_JPG.rf.34c25bed949954d12bb79b4b23398332.xml
#  extracting: train/IMG_4965_JPG.rf.4038e360a21ed4cdb2bfc4cfbc0dc0f8.jpg
#   inflating: train/IMG_4965_JPG.rf.4038e360a21ed4cdb2bfc4cfbc0dc0f8.xml
#  extracting: train/IMG_4965_JPG.rf.4fa1addb83e0abf96c4620b02077e30f.jpg
#   inflating: train/IMG_4965_JPG.rf.4fa1addb83e0abf96c4620b02077e30f.xml
#  extracting: train/IMG_4965_JPG.rf.5686019f04beb759cdf3105f2417aa9a.jpg
#   inflating: train/IMG_4965_JPG.rf.5686019f04beb759cdf3105f2417aa9a.xml
#  extracting: train/IMG_4965_JPG.rf.58d16fcc2f6d434b73259fc00867a651.jpg
#   inflating: train/IMG_4965_JPG.rf.58d16fcc2f6d434b73259fc00867a651.xml
#  extracting: train/IMG_4965_JPG.rf.5b32a3dd1b9f1b98a1a8f5f9ea15984d.jpg
#   inflating: train/IMG_4965_JPG.rf.5b32a3dd1b9f1b98a1a8f5f9ea15984d.xml
#  extracting: train/IMG_4965_JPG.rf.6107d14d76306a2f36341073a6f457e3.jpg
#   inflating: train/IMG_4965_JPG.rf.6107d14d76306a2f36341073a6f457e3.xml
#  extracting: train/IMG_4965_JPG.rf.695c21068a308c13be6f4b3e9b7ff0ae.jpg
#   inflating: train/IMG_4965_JPG.rf.695c21068a308c13be6f4b3e9b7ff0ae.xml
#  extracting: train/IMG_4965_JPG.rf.70e963d734ecc7b2762846c2d3675af1.jpg
#   inflating: train/IMG_4965_JPG.rf.70e963d734ecc7b2762846c2d3675af1.xml
#  extracting: train/IMG_4965_JPG.rf.76877b1d120bbb2cf1f9de9d0aa2cec6.jpg
#   inflating: train/IMG_4965_JPG.rf.76877b1d120bbb2cf1f9de9d0aa2cec6.xml
#  extracting: train/IMG_4965_JPG.rf.8415431baf0f2172a1916ae3be3d661d.jpg
#   inflating: train/IMG_4965_JPG.rf.8415431baf0f2172a1916ae3be3d661d.xml
#  extracting: train/IMG_4965_JPG.rf.8ec8cc192ebad6de2b2c9db5401f3c2a.jpg
#   inflating: train/IMG_4965_JPG.rf.8ec8cc192ebad6de2b2c9db5401f3c2a.xml
#  extracting: train/IMG_4965_JPG.rf.900588d9566e6eb7fe25aed4abe29d80.jpg
#   inflating: train/IMG_4965_JPG.rf.900588d9566e6eb7fe25aed4abe29d80.xml
#  extracting: train/IMG_4965_JPG.rf.9ce1d816d03792602d0efc10f51703eb.jpg
#   inflating: train/IMG_4965_JPG.rf.9ce1d816d03792602d0efc10f51703eb.xml
#  extracting: train/IMG_4965_JPG.rf.a547d064fb1b97615b3855658cecb0a1.jpg
#   inflating: train/IMG_4965_JPG.rf.a547d064fb1b97615b3855658cecb0a1.xml
#  extracting: train/IMG_4965_JPG.rf.aa663be0065fd97b571bd807ecb3015b.jpg
#   inflating: train/IMG_4965_JPG.rf.aa663be0065fd97b571bd807ecb3015b.xml
#  extracting: train/IMG_4965_JPG.rf.b66fb287a9ae593976c2de40f09b5657.jpg
#   inflating: train/IMG_4965_JPG.rf.b66fb287a9ae593976c2de40f09b5657.xml
#  extracting: train/IMG_4965_JPG.rf.b715c5badcf4b97d4659196b98175fbb.jpg
#   inflating: train/IMG_4965_JPG.rf.b715c5badcf4b97d4659196b98175fbb.xml
#  extracting: train/IMG_4965_JPG.rf.bc3602fae1c76ea2dce9cbc2d14a6132.jpg
#   inflating: train/IMG_4965_JPG.rf.bc3602fae1c76ea2dce9cbc2d14a6132.xml
#  extracting: train/IMG_4965_JPG.rf.c33f89a4ea4b1769a0994ee30cb27cbf.jpg
#   inflating: train/IMG_4965_JPG.rf.c33f89a4ea4b1769a0994ee30cb27cbf.xml
#  extracting: train/IMG_4965_JPG.rf.c8c0a4ef9ff037f7dfc3d9148164696c.jpg
#   inflating: train/IMG_4965_JPG.rf.c8c0a4ef9ff037f7dfc3d9148164696c.xml
#  extracting: train/IMG_4965_JPG.rf.c9049c60308d5c26d87297fa27f09fee.jpg
#   inflating: train/IMG_4965_JPG.rf.c9049c60308d5c26d87297fa27f09fee.xml
#  extracting: train/IMG_4965_JPG.rf.cc34dbfb966caea371cfbc7bdf9e5d34.jpg
#   inflating: train/IMG_4965_JPG.rf.cc34dbfb966caea371cfbc7bdf9e5d34.xml
#  extracting: train/IMG_4965_JPG.rf.ceeccf6ee8ac1f5c18dafcad4634e74b.jpg
#   inflating: train/IMG_4965_JPG.rf.ceeccf6ee8ac1f5c18dafcad4634e74b.xml
#  extracting: train/IMG_4965_JPG.rf.d09aba43d195bae732e2a246d0533e01.jpg
#   inflating: train/IMG_4965_JPG.rf.d09aba43d195bae732e2a246d0533e01.xml
#  extracting: train/IMG_4965_JPG.rf.e02478e2143c5b533f41bf87d738f624.jpg
#   inflating: train/IMG_4965_JPG.rf.e02478e2143c5b533f41bf87d738f624.xml
#  extracting: train/IMG_4965_JPG.rf.e7faf07341953106bee54817a873d158.jpg
#   inflating: train/IMG_4965_JPG.rf.e7faf07341953106bee54817a873d158.xml
#  extracting: train/IMG_4965_JPG.rf.f0ac25f29ce36b491788d3bea3263a21.jpg
#   inflating: train/IMG_4965_JPG.rf.f0ac25f29ce36b491788d3bea3263a21.xml
#  extracting: train/IMG_4965_JPG.rf.f3b419770f2c063aeddaaef59fb7ba34.jpg
#   inflating: train/IMG_4965_JPG.rf.f3b419770f2c063aeddaaef59fb7ba34.xml
#  extracting: train/IMG_4965_JPG.rf.f4a7b3769084c02e7c283d3582ef3147.jpg
#   inflating: train/IMG_4965_JPG.rf.f4a7b3769084c02e7c283d3582ef3147.xml
#  extracting: train/IMG_4965_JPG.rf.fa2d3455860fc10ab88efe22ceaef31b.jpg
#   inflating: train/IMG_4965_JPG.rf.fa2d3455860fc10ab88efe22ceaef31b.xml
#  extracting: train/IMG_4965_JPG.rf.fad7b54981770f9cff0dcc6bef436117.jpg
#   inflating: train/IMG_4965_JPG.rf.fad7b54981770f9cff0dcc6bef436117.xml
#  extracting: train/IMG_4965_JPG.rf.fc6f3140523a2a9cd3662e10c91a3fdc.jpg
#   inflating: train/IMG_4965_JPG.rf.fc6f3140523a2a9cd3662e10c91a3fdc.xml
#  extracting: train/IMG_4965_JPG.rf.fd9b4668b2b2257953f1d5757b712762.jpg
#   inflating: train/IMG_4965_JPG.rf.fd9b4668b2b2257953f1d5757b712762.xml
#  extracting: train/IMG_4968_JPG.rf.034c2f6dca7e3a80517d9866b7846330.jpg
#   inflating: train/IMG_4968_JPG.rf.034c2f6dca7e3a80517d9866b7846330.xml
#  extracting: train/IMG_4968_JPG.rf.0be0a899d936cc1f0ac11f5321267002.jpg
#   inflating: train/IMG_4968_JPG.rf.0be0a899d936cc1f0ac11f5321267002.xml
#  extracting: train/IMG_4968_JPG.rf.111e89e5905330f5e0a351a507c11e66.jpg
#   inflating: train/IMG_4968_JPG.rf.111e89e5905330f5e0a351a507c11e66.xml
#  extracting: train/IMG_4968_JPG.rf.198c395aa48dca30a359628d6fa83807.jpg
#   inflating: train/IMG_4968_JPG.rf.198c395aa48dca30a359628d6fa83807.xml
#  extracting: train/IMG_4968_JPG.rf.1ea661d93f331af76715b3177b0dbba5.jpg
#   inflating: train/IMG_4968_JPG.rf.1ea661d93f331af76715b3177b0dbba5.xml
#  extracting: train/IMG_4968_JPG.rf.1ef2618b5eb52c93b9c7c663281320d5.jpg
#   inflating: train/IMG_4968_JPG.rf.1ef2618b5eb52c93b9c7c663281320d5.xml
#  extracting: train/IMG_4968_JPG.rf.30ed300106f8c69d7f7ba58fc57406d6.jpg
#   inflating: train/IMG_4968_JPG.rf.30ed300106f8c69d7f7ba58fc57406d6.xml
#  extracting: train/IMG_4968_JPG.rf.3b859f80586bdade89d581273da0bcb2.jpg
#   inflating: train/IMG_4968_JPG.rf.3b859f80586bdade89d581273da0bcb2.xml
#  extracting: train/IMG_4968_JPG.rf.3e71bc02ba8fb4e2efeb506d6bd57b42.jpg
#   inflating: train/IMG_4968_JPG.rf.3e71bc02ba8fb4e2efeb506d6bd57b42.xml
#  extracting: train/IMG_4968_JPG.rf.411801f92413186c0e10e2a1f3b603a1.jpg
#   inflating: train/IMG_4968_JPG.rf.411801f92413186c0e10e2a1f3b603a1.xml
#  extracting: train/IMG_4968_JPG.rf.4383b3eb58d20f8a67eb41632af2122b.jpg
#   inflating: train/IMG_4968_JPG.rf.4383b3eb58d20f8a67eb41632af2122b.xml
#  extracting: train/IMG_4968_JPG.rf.70558aa5a68fc3aa75bb45b5e68d59be.jpg
#   inflating: train/IMG_4968_JPG.rf.70558aa5a68fc3aa75bb45b5e68d59be.xml
#  extracting: train/IMG_4968_JPG.rf.72c52bcca993e33ce38ec3476f01b2d7.jpg
#   inflating: train/IMG_4968_JPG.rf.72c52bcca993e33ce38ec3476f01b2d7.xml
#  extracting: train/IMG_4968_JPG.rf.7d9f8449c456af92a551bbce64958e67.jpg
#   inflating: train/IMG_4968_JPG.rf.7d9f8449c456af92a551bbce64958e67.xml
#  extracting: train/IMG_4968_JPG.rf.7dbb34e07674355e352868b93aa3326f.jpg
#   inflating: train/IMG_4968_JPG.rf.7dbb34e07674355e352868b93aa3326f.xml
#  extracting: train/IMG_4968_JPG.rf.7f70bdb21db882c32d59be9fbe32a70c.jpg
#   inflating: train/IMG_4968_JPG.rf.7f70bdb21db882c32d59be9fbe32a70c.xml
#  extracting: train/IMG_4968_JPG.rf.822e71092e63d49c64f8aad8ca89654e.jpg
#   inflating: train/IMG_4968_JPG.rf.822e71092e63d49c64f8aad8ca89654e.xml
#  extracting: train/IMG_4968_JPG.rf.82dfeea76934f08a1a9118faeb4a7968.jpg
#   inflating: train/IMG_4968_JPG.rf.82dfeea76934f08a1a9118faeb4a7968.xml
#  extracting: train/IMG_4968_JPG.rf.83687672aa1e6171a5c51934d1ce1788.jpg
#   inflating: train/IMG_4968_JPG.rf.83687672aa1e6171a5c51934d1ce1788.xml
#  extracting: train/IMG_4968_JPG.rf.872d30c545e74f8b191952c47ef39117.jpg
#   inflating: train/IMG_4968_JPG.rf.872d30c545e74f8b191952c47ef39117.xml
#  extracting: train/IMG_4968_JPG.rf.8832fae7ec0768b18e522b902b44854c.jpg
#   inflating: train/IMG_4968_JPG.rf.8832fae7ec0768b18e522b902b44854c.xml
#  extracting: train/IMG_4968_JPG.rf.88503381afb4df2e822e78b8b0568c23.jpg
#   inflating: train/IMG_4968_JPG.rf.88503381afb4df2e822e78b8b0568c23.xml
#  extracting: train/IMG_4968_JPG.rf.89e0f18c6701366b187e8d6614270036.jpg
#   inflating: train/IMG_4968_JPG.rf.89e0f18c6701366b187e8d6614270036.xml
#  extracting: train/IMG_4968_JPG.rf.9bd2cbace096ef015730bd8ef64c8c80.jpg
#   inflating: train/IMG_4968_JPG.rf.9bd2cbace096ef015730bd8ef64c8c80.xml
#  extracting: train/IMG_4968_JPG.rf.9e136a8ec9e019641ad2da5c8cf16cd5.jpg
#   inflating: train/IMG_4968_JPG.rf.9e136a8ec9e019641ad2da5c8cf16cd5.xml
#  extracting: train/IMG_4968_JPG.rf.a997493834248ca81516e3f83aeb8890.jpg
#   inflating: train/IMG_4968_JPG.rf.a997493834248ca81516e3f83aeb8890.xml
#  extracting: train/IMG_4968_JPG.rf.ae4469cc6200bf9828f4ea9d80e4af63.jpg
#   inflating: train/IMG_4968_JPG.rf.ae4469cc6200bf9828f4ea9d80e4af63.xml
#  extracting: train/IMG_4968_JPG.rf.aefca1339edd1319b83f4ff342ae6b0d.jpg
#   inflating: train/IMG_4968_JPG.rf.aefca1339edd1319b83f4ff342ae6b0d.xml
#  extracting: train/IMG_4968_JPG.rf.b008938871e571f31cacf9cbe515af74.jpg
#   inflating: train/IMG_4968_JPG.rf.b008938871e571f31cacf9cbe515af74.xml
#  extracting: train/IMG_4968_JPG.rf.c386c5380fe51b24dc809348daa8f9bd.jpg
#   inflating: train/IMG_4968_JPG.rf.c386c5380fe51b24dc809348daa8f9bd.xml
#  extracting: train/IMG_4968_JPG.rf.c8fbe6e8cd1f87481c94ea827e79bfb7.jpg
#   inflating: train/IMG_4968_JPG.rf.c8fbe6e8cd1f87481c94ea827e79bfb7.xml
#  extracting: train/IMG_4968_JPG.rf.c947bb3015152d9b565358f409bc222c.jpg
#   inflating: train/IMG_4968_JPG.rf.c947bb3015152d9b565358f409bc222c.xml
#  extracting: train/IMG_4968_JPG.rf.ca2c1ba5df237d275194c10c1fc4c45b.jpg
#   inflating: train/IMG_4968_JPG.rf.ca2c1ba5df237d275194c10c1fc4c45b.xml
#  extracting: train/IMG_4968_JPG.rf.cd7648afab4eabb72e2f2f92ba9982da.jpg
#   inflating: train/IMG_4968_JPG.rf.cd7648afab4eabb72e2f2f92ba9982da.xml
#  extracting: train/IMG_4968_JPG.rf.d00cb2adfb08e14d5b5fd7c9b4b189cb.jpg
#   inflating: train/IMG_4968_JPG.rf.d00cb2adfb08e14d5b5fd7c9b4b189cb.xml
#  extracting: train/IMG_4968_JPG.rf.e3845318533ad13743c402dfb2bdd9a5.jpg
#   inflating: train/IMG_4968_JPG.rf.e3845318533ad13743c402dfb2bdd9a5.xml
#  extracting: train/IMG_4968_JPG.rf.f3548a7a87c4b350e61a5d371443d8f5.jpg
#   inflating: train/IMG_4968_JPG.rf.f3548a7a87c4b350e61a5d371443d8f5.xml
#  extracting: train/IMG_4968_JPG.rf.fbf976b2e6a536ff30f71ebc46bbf17a.jpg
#   inflating: train/IMG_4968_JPG.rf.fbf976b2e6a536ff30f71ebc46bbf17a.xml
#  extracting: train/IMG_4968_JPG.rf.fc0b4850b18ca4df47a56634792dadc3.jpg
#   inflating: train/IMG_4968_JPG.rf.fc0b4850b18ca4df47a56634792dadc3.xml
#  extracting: train/IMG_4968_JPG.rf.fc837a3686ffb4f6dfeb7f3ef00832b4.jpg
#   inflating: train/IMG_4968_JPG.rf.fc837a3686ffb4f6dfeb7f3ef00832b4.xml

# %%
import os
import fnmatch

def find_files(directory, pattern):
    for root, dirs, files in os.walk(directory):
        for basename in files:
            if fnmatch.fnmatch(basename, pattern):
                filename = os.path.join(root, basename)
                yield filename

def set_tfrecord_variables(directory):
    train_record_fname = ''
    val_record_fname = ''
    label_map_pbtxt_fname = ''

    for tfrecord_file in find_files(directory, '*.tfrecord'):
        if '/train/' in tfrecord_file:
            train_record_fname = tfrecord_file
        elif '/valid/' in tfrecord_file:
            val_record_fname = tfrecord_file
        elif '/test/' in tfrecord_file:
            pass

    for label_map_file in find_files(directory, '*_label_map.pbtxt'):
        label_map_pbtxt_fname = label_map_file  # Assuming one common label map file

    return train_record_fname, val_record_fname, label_map_pbtxt_fname


train_record_fname, val_record_fname, label_map_pbtxt_fname = set_tfrecord_variables('/content')

#if(MLENVIRONMENT=="COLAB"):
    #train_record_fname = '/content/train/cubes-cones.tfrecord'
    #val_record_fname = '/content/valid/cubes-cones.tfrecord'
    #label_map_pbtxt_fname = '/content/train/cubes-cones_label_map.pbtxt'

print("Train Record File:", train_record_fname)
print("Validation Record File:", val_record_fname)
print("Label Map File:", label_map_pbtxt_fname)

# %% [markdown]
# # 3.&nbsp;Training Configuration and Labels File Generation

# %% [markdown]
# Download the pre-trained Limelight Base Model

# %%
chosen_model = 'ssd-mobilenet-v2'
MODELS_CONFIG = {
    'ssd-mobilenet-v2': {
        'model_name': 'ssd_mobilenet_v2_320x320_coco17_tpu-8',
        'base_pipeline_file': 'limelight_ssd_mobilenet_v2_320x320_coco17_tpu-8.config',
        'pretrained_checkpoint': 'limelight_ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz',
    },
}
model_name = MODELS_CONFIG[chosen_model]['model_name']
pretrained_checkpoint = MODELS_CONFIG[chosen_model]['pretrained_checkpoint']
base_pipeline_file = MODELS_CONFIG[chosen_model]['base_pipeline_file']

# Create "mymodel" folder for pre-trained weights and configuration files
# %cd ~
# %mkdir {HOMEFOLDER}models/mymodel/
# %cd {HOMEFOLDER}models/mymodel/
# %pwd

# Download pre-trained model weights
import tarfile
download_tar = 'https://downloads.limelightvision.io/models/' + pretrained_checkpoint
# !wget {download_tar}
tar = tarfile.open(pretrained_checkpoint)
tar.extractall()
tar.close()

# Download training configuration file for model
download_config = 'https://downloads.limelightvision.io/models/' + base_pipeline_file
# !wget {download_config}
# %cd ~

# Set training parameters for the model
num_steps = 40000
checkpoint_every = 2000
batch_size = 16

# %% [markdown]
# Generate Labels File

# %%
# Set file locations and get number of classes for config file
pipeline_fname = HOMEFOLDER+'models/mymodel/' + base_pipeline_file
fine_tune_checkpoint = HOMEFOLDER+'models/mymodel/' + model_name + '/checkpoint/ckpt-0'

def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())

def get_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)

    class_names = [category['name'] for category in category_index.values()]
    return class_names

def create_label_file(filename, labels):
    with open(filename, 'w') as file:
        for label in labels:
            file.write(label + '\n')


num_classes = get_num_classes(label_map_pbtxt_fname)
classes = get_classes(label_map_pbtxt_fname)

print('Total classes:', num_classes)
print(classes)


#Generate labels file
create_label_file(HOMEFOLDER + "limelight_neural_detector_labels.txt", classes)

# %% [markdown]
# Modify the base Limelight Model Configuration File
#
# Augmentation Options: https://github.com/tensorflow/models/blob/master/research/object_detection/protos/preprocessor.proto

# %%
# Create custom configuration file by writing the dataset, model checkpoint, and training parameters into the base pipeline file
import re

print('writing custom configuration file')



with open(pipeline_fname) as f:
    s = f.read()
with open('pipeline_file.config', 'w') as f:

    # Set fine_tune_checkpoint path
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), s)

    # Set tfrecord files for train and test datasets
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/train)(.*?")', 'input_path: "{}"'.format(train_record_fname), s)
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/val)(.*?")', 'input_path: "{}"'.format(val_record_fname), s)

    # Set label_map_path
    s = re.sub(
        'label_map_path: ".*?"', 'label_map_path: "{}"'.format(label_map_pbtxt_fname), s)

    # Set batch_size
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)

    # Set number of classes num_classes
    s = re.sub('checkpoint_every_n: [0-9]+',
               'num_classes: {}'.format(num_classes), s)

    # Change fine-tune checkpoint type from "classification" to "detection"
    s = re.sub(
        'fine_tune_checkpoint_type: "classification"', 'fine_tune_checkpoint_type: "{}"'.format('detection'), s)

    # If using ssd-mobilenet-v2, reduce learning rate
    if chosen_model == 'ssd-mobilenet-v2':
      s = re.sub('learning_rate_base: .8',
                 'learning_rate_base: .004', s)

      s = re.sub('warmup_learning_rate: 0.13333',
                 'warmup_learning_rate: .0016666', s)

    # If using efficientdet-d0, use fixed_shape_resizer instead of keep_aspect_ratio_resizer (because it isn't supported by TFLite)
    if chosen_model == 'efficientdet-d0':
      s = re.sub('keep_aspect_ratio_resizer', 'fixed_shape_resizer', s)
      s = re.sub('pad_to_max_dimension: true', '', s)
      s = re.sub('min_dimension', 'height', s)
      s = re.sub('max_dimension', 'width', s)

    f.write(s)

# (Optional) Display the custom configuration file's contents
# !cat pipeline_file.config
# Set the path to the custom config file and the directory to store training checkpoints in
pipeline_file = 'pipeline_file.config'
model_dir = HOMEFOLDER+'training_progress/'
print(" ")
print(model_dir)

# %% [markdown]
# # 4.&nbsp;Train Model

# %% [markdown]
# Once training starts, come back and click the refresh button within the tensorboard window to check training progress.

# %%
# %load_ext tensorboard
# %tensorboard --logdir '/content/training_progress/train'

# %% [markdown]
# Fix TF 2.15 breaking changes

# %%
import shutil
import re

original_path = '/usr/local/lib/python3.11/dist-packages/tf_slim/data/tfexample_decoder.py'
with open(original_path, 'r') as file:
  content = file.read()
  content = re.sub(r'import abc', 'import tensorflow as tf\n\nimport abc', content)
  content = re.sub(r'control_flow_ops.case', 'tf.case', content)
  content = re.sub(r'control_flow_ops.cond', 'tf.compat.v1.cond', content)
with open(original_path, 'w') as file:
  file.write(content)

print(f"File {original_path} fixed.")

# %% [markdown]
# Train

# %%
# !rm -rf {HOMEFOLDER}training_progress
# Run training!
# !python {HOMEFOLDER}models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_file} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --checkpoint_every_n={checkpoint_every} \
    --num_train_steps={num_steps} \
    --num_workers=2 \
    --sample_1_of_n_eval_examples=1

# %% [markdown]
# Feel free to stop training early. Check the 'training_progress' folder to see all training checkpoints.

# %% [markdown]
# # 5.&nbsp;Convert Model to TFLite

# %%
#remove final output folder if it exists
if os.path.exists(FINALOUTPUTFOLDER) and os.path.isdir(FINALOUTPUTFOLDER):
  shutil.rmtree(FINALOUTPUTFOLDER)

# Make a directory to store the trained TFLite model
# !mkdir {FINALOUTPUTFOLDER}
print(FINALOUTPUTFOLDER)
# Export graph
# Path to training directory (the conversion script automatically chooses the highest checkpoint file)
last_model_path = HOMEFOLDER+'training_progress'
exporter_path = HOMEFOLDER+'models/research/object_detection/export_tflite_graph_tf2.py'
output_directory = FINALOUTPUTFOLDER

# !python $exporter_path \
    --trained_checkpoint_dir $last_model_path \
    --output_directory $output_directory \
    --pipeline_config_path $pipeline_file

# Convert to .tflite Flatbuffer
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_saved_model(FINALOUTPUTFOLDER+'/saved_model')
tflite_model = converter.convert()
model_path_32bit = FINALOUTPUTFOLDER+'/limelight_neural_detector_32bit.tflite'
with open(model_path_32bit, 'wb') as f:
  f.write(tflite_model)

# !cp {HOMEFOLDER}limelight_neural_detector_labels.txt {FINALOUTPUTFOLDER}
# !cp {HOMEFOLDER}models/mymodel/pipeline_file.config {FINALOUTPUTFOLDER}

# %%
# Export graph
# Path to training directory (the conversion script automatically chooses the highest checkpoint file)
last_model_path = HOMEFOLDER+'training_progress'
exporter_path = HOMEFOLDER+'models/research/object_detection/export_tflite_graph_tf2.py'
output_directory = FINALOUTPUTFOLDER

# !python $exporter_path \
    --trained_checkpoint_dir $last_model_path \
    --output_directory $output_directory \
    --pipeline_config_path $pipeline_file

# Convert to .tflite Flatbuffer
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_saved_model(FINALOUTPUTFOLDER+'/saved_model')
tflite_model = converter.convert()
model_path_32bit = FINALOUTPUTFOLDER+'/limelight_neural_detector_32bit.tflite'
with open(model_path_32bit, 'wb') as f:
  f.write(tflite_model)

# !cp {HOMEFOLDER}limelight_neural_detector_labels.txt {FINALOUTPUTFOLDER}

# %% [markdown]
# # 6. Quantize model
# The "TFLiteConverter" module will perform [post-training quantization](https://www.tensorflow.org/lite/performance/post_training_quantization) on the model. To quantize the model, we need to provide a set of example images. We will extract 100 images from the training tfrecord and place said images into the "extracted_samples" folder.

# %%
import tensorflow as tf
import os
import io
from PIL import Image

def extract_images_from_tfrecord(tfrecord_path, output_folder, num_samples=100):
    # Make sure the output directory exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Initialize a counter for the number of images saved
    saved_images = 0

    # Read the TFRecord file
    raw_dataset = tf.data.TFRecordDataset(tfrecord_path)
    for raw_record in raw_dataset.take(num_samples):
        example = tf.train.Example()
        example.ParseFromString(raw_record.numpy())

        # Extract the image data (change 'image/encoded' if necessary)
        image_data = example.features.feature['image/encoded'].bytes_list.value[0]

        # Decode the image data and save as a file
        image = Image.open(io.BytesIO(image_data))
        image.save(os.path.join(output_folder, f'image_{saved_images}.png'))

        saved_images += 1
        if saved_images >= num_samples:
            break

    print(f"Extracted {saved_images} images to {output_folder}")

# Set the path to your TFRecord file and the output directory
tfrecord_path = train_record_fname
extracted_sample_folder = HOMEFOLDER+'extracted_samples'

#remove sample folder if it exists
if os.path.exists(extracted_sample_folder) and os.path.isdir(extracted_sample_folder):
  shutil.rmtree(extracted_sample_folder)

# Extract images
extract_images_from_tfrecord(tfrecord_path, extracted_sample_folder)


# Get list of all images in train directory
from google.cloud import storage
import glob

quant_image_list=[]
if(MLENVIRONMENT=="COLAB"):

    jpg_file_list = glob.glob(extracted_sample_folder + '/*.jpg')
    jpeg_file_list = glob.glob(extracted_sample_folder + '/*.jpeg')
    JPG_file_list = glob.glob(extracted_sample_folder + '/*.JPG')
    png_file_list = glob.glob(extracted_sample_folder + '/*.png')
    bmp_file_list = glob.glob(extracted_sample_folder + '/*.bmp')
    quant_image_list = jpg_file_list + JPG_file_list + png_file_list + bmp_file_list

print("pulling samples from " + extracted_sample_folder)
print("samples: " + str(len(quant_image_list)))

# %%
# A generator that provides a representative dataset
# Code modified from https://colab.research.google.com/github/google-coral/tutorials/blob/master/retrain_classification_ptq_tf2.ipynb

# First, get input details for model so we know how to preprocess images
interpreter = tf.lite.Interpreter(model_path=model_path_32bit)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
height = input_details[0]['shape'][1]
width = input_details[0]['shape'][2]

import random

def representative_data_gen():
  dataset_list = quant_image_list
  quant_num = 300
  for i in range(quant_num):
    pick_me = random.choice(dataset_list)
    print(pick_me)
    image = tf.io.read_file(pick_me)

    if pick_me.endswith('.jpg') or pick_me.endswith('.JPG') or pick_me.endswith('.jpeg'):
      image = tf.io.decode_jpeg(image, channels=3)
    elif pick_me.endswith('.png'):
      image = tf.io.decode_png(image, channels=3)
    elif pick_me.endswith('.bmp'):
      image = tf.io.decode_bmp(image, channels=3)

    image = tf.image.resize(image, [width, height])  # TO DO: Replace 300s with an automatic way of reading network input size
    image = tf.cast(image / 255., tf.float32)
    image = tf.expand_dims(image, 0)
    yield [image]

# %% [markdown]
# Finally, we'll initialize the TFLiteConverter module, point it at the TFLite graph we generated in Step 6, and provide it with the representative dataset generator function we created in the previous code block. We'll configure the converter to quantize the model's weight values to INT8 format.

# %%
# Initialize converter module
converter = tf.lite.TFLiteConverter.from_saved_model(FINALOUTPUTFOLDER+'/saved_model')
print("initialized converter")
# This enables quantization
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# This sets the representative dataset for quantization
converter.representative_dataset = representative_data_gen
# This ensures that if any ops can't be quantized, the converter throws an error
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
# For full integer quantization, though supported types defaults to int8 only, we explicitly declare it for clarity.
converter.target_spec.supported_types = [tf.int8]
# These set the input tensors to uint8 and output tensors to float32
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.float32
print("begin conversion")
tflite_model = converter.convert()
print("conversion complete")

with open(FINALOUTPUTFOLDER+'/limelight_neural_detector_8bit.tflite', 'wb') as f:
  f.write(tflite_model)

# %% [markdown]
# # 7. Compile Model for Limelight & Download

# %% [markdown]
# Install Coral Compiler

# %%
! curl https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo apt-key add -
! echo "deb https://packages.cloud.google.com/apt coral-edgetpu-stable main" | sudo tee /etc/apt/sources.list.d/coral-edgetpu.list
! sudo apt-get update
! sudo apt-get install edgetpu-compiler

# %% [markdown]
# Compile the previously-generated 8-bit model for Google Coral

# %%
# !cd {FINALOUTPUTFOLDER} && pwd && edgetpu_compiler limelight_neural_detector_8bit.tflite && pwd && mv limelight_neural_detector_8bit_edgetpu.tflite limelight_neural_detector_coral.tflite && rm limelight_neural_detector_8bit_edgetpu.log

# %% [markdown]
# Zip models

# %%
# !rm {HOMEFOLDER}limelight_detectors.zip
# !zip -r {HOMEFOLDER}limelight_detectors.zip {FINALOUTPUTFOLDER}

# %% [markdown]
# Download

# %%
from google.colab import files
files.download(HOMEFOLDER+'limelight_detectors.zip')
